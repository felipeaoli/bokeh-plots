# %%
import numpy as np
from bokeh.plotting import output_notebook
from bokeh.plotting import figure, show
#from bokeh.plotting import output_file
import numpy as np
import bokeh.plotting as bk # Open output here and prevent to open in another tab
bk.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3bc87ad7-3403-4197-9123-997b82184807">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.layouts import row
#from bokeh.plotting import figure, show#, output_file

factors = ["a", "b", "c", "d", "e", "f", "g", "h"]
x =  [50, 40, 65, 10, 25, 37, 80, 60]

dot = figure(title="Categorical Dot Plot", tools="", toolbar_location=None,
            y_range=factors, x_range=[0,100])

dot.segment(0, factors, x, factors, line_width=2, line_color="green", )
dot.circle(x, factors, size=15, fill_color="orange", line_color="green", line_width=3, )

factors = ["foo 123", "bar:0.2", "baz-10"]
x = ["foo 123", "foo 123", "foo 123", "bar:0.2", "bar:0.2"
     , "bar:0.2", "baz-10",  "baz-10",  "baz-10"]
y = ["foo 123", "bar:0.2", "baz-10",  "foo 123", "bar:0.2"
     , "baz-10",  "foo 123", "bar:0.2", "baz-10"]
colors = [
    "#0B486B", "#79BD9A", "#CFF09E",
    "#79BD9A", "#0B486B", "#79BD9A",
    "#CFF09E", "#79BD9A", "#0B486B"
]

hm = figure(title="Categorical Heatmap", tools="hover", toolbar_location=None,
            x_range=factors, y_range=factors)

hm.rect(x, y, color=colors, width=1, height=1)

#output_file("categorical.html", title="categorical.py example")

show(row(hm, dot, sizing_mode="scale_width"))  # open a browser
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="56d05e00-c321-4431-89ca-5bc499b44a08"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("56d05e00-c321-4431-89ca-5bc499b44a08").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("56d05e00-c321-4431-89ca-5bc499b44a08");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '56d05e00-c321-4431-89ca-5bc499b44a08' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b32c3ac9-d7f7-4c43-ba5e-3298b57d3d8c":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"7b766269-cbfb-4915-8582-b41cff6d28b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"c7f6957f-76f9-42ae-887a-845483f6ec44","type":"CategoricalTicker"}},"id":"0c340c55-5898-41fb-b227-4b8df277f118","type":"Grid"},{"attributes":{"callback":null,"plot":{"id":"7b766269-cbfb-4915-8582-b41cff6d28b4","subtype":"Figure","type":"Plot"}},"id":"2f631ed7-db19-4138-b6c9-1d83623cf215","type":"HoverTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2f631ed7-db19-4138-b6c9-1d83623cf215","type":"HoverTool"}]},"id":"c127fc43-3a61-4d49-b1a2-6840b4dcb434","type":"Toolbar"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto"},"id":"f7437c15-e3fa-49e4-bf4f-95e967756628","type":"Toolbar"},{"attributes":{},"id":"20b59132-0ab8-4974-ba9e-843b3f116cf3","type":"BasicTicker"},{"attributes":{},"id":"46146b91-1d98-4b33-8488-baf13cdadc31","type":"CategoricalTickFormatter"},{"attributes":{"fill_color":{"field":"fill_color"},"height":{"units":"data","value":1},"line_color":{"field":"line_color"},"width":{"units":"data","value":1},"x":{"field":"x"},"y":{"field":"y"}},"id":"53bcb811-2de9-49f2-9b98-2ff8c2d07c86","type":"Rect"},{"attributes":{},"id":"58ab5344-e97b-4651-aa94-2f58b65cddb1","type":"ToolEvents"},{"attributes":{"below":[{"id":"d659c43c-c5db-4d1a-9cb2-04b651f2c368","type":"CategoricalAxis"}],"left":[{"id":"3002c021-e900-4e5c-90a8-b93a022c5d8a","type":"CategoricalAxis"}],"renderers":[{"id":"d659c43c-c5db-4d1a-9cb2-04b651f2c368","type":"CategoricalAxis"},{"id":"b1c02aa5-2032-45e1-8b38-2b0e870ec394","type":"Grid"},{"id":"3002c021-e900-4e5c-90a8-b93a022c5d8a","type":"CategoricalAxis"},{"id":"0c340c55-5898-41fb-b227-4b8df277f118","type":"Grid"},{"id":"42650e1c-35ad-47f8-bf37-778238a9cf8a","type":"GlyphRenderer"}],"sizing_mode":"scale_width","title":{"id":"ff52229d-4298-4ed2-b5ba-01589d8180f6","type":"Title"},"tool_events":{"id":"58ab5344-e97b-4651-aa94-2f58b65cddb1","type":"ToolEvents"},"toolbar":{"id":"c127fc43-3a61-4d49-b1a2-6840b4dcb434","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"356b0fc7-e618-4a24-a58b-e210934948db","type":"FactorRange"},"y_range":{"id":"6b4c2044-f58a-4e96-9936-33dc239cc8fd","type":"FactorRange"}},"id":"7b766269-cbfb-4915-8582-b41cff6d28b4","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["y0","x1","y1"],"data":{"x1":[50,40,65,10,25,37,80,60],"y0":["a","b","c","d","e","f","g","h"],"y1":["a","b","c","d","e","f","g","h"]}},"id":"5452f2c2-f105-40ec-a218-df168d0bbfcd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c5ce523-4c9e-4c12-9854-0799f9816e6d","type":"Circle"},{"attributes":{"children":[{"id":"7b766269-cbfb-4915-8582-b41cff6d28b4","subtype":"Figure","type":"Plot"},{"id":"b4defa20-91c4-4196-9ab9-e4bfdf3bbbfa","subtype":"Figure","type":"Plot"}],"sizing_mode":"scale_width"},"id":"6d14f064-0144-49fe-9d60-3b9cde4aa7c8","type":"Row"},{"attributes":{},"id":"e39ecc18-952a-493b-af46-b0c593a3a42e","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x0":{"value":0},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"4f332965-182e-4f55-8e94-f680e1aa82df","type":"Segment"},{"attributes":{"dimension":1,"plot":{"id":"b4defa20-91c4-4196-9ab9-e4bfdf3bbbfa","subtype":"Figure","type":"Plot"},"ticker":{"id":"62ce809d-1c32-4739-919b-4710035dcb59","type":"CategoricalTicker"}},"id":"904477c0-7b06-4dac-88ab-75b3620e8878","type":"Grid"},{"attributes":{},"id":"f12951d8-8ed2-470d-b96a-6859d9b409f7","type":"CategoricalTickFormatter"},{"attributes":{},"id":"d300181d-844d-4ba0-b54c-96f6a7b4ad41","type":"Ca ...

# %%
from __future__ import division

import numpy as np

from bokeh.plotting import figure, show

N = 2
img = np.empty((N,N), dtype=np.uint32)
view = img.view(dtype=np.uint8).reshape((N, N, 4))
for i in range(N):
    for j in range(N):
        view[i, j, 0] = int(i/N*255)
        view[i, j, 1] = 158
        view[i, j, 2] = int(j/N*255)
        view[i, j, 3] = 255

p = figure(x_range=(0,10), y_range=(0,10))
print(img)
# must give a vector of images
p.image_rgba(image=[img], x=0, y=0, dw=10, dh=10)

#output_file("image_rgba.html", title="image_rgba.py example")
show(p)  # open a browser
# Out:
# [[4278230528 4286553600]
#  [4278230655 4286553727]]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="79531810-3014-4f69-ba5d-aa3b77b54413"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("79531810-3014-4f69-ba5d-aa3b77b54413").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("79531810-3014-4f69-ba5d-aa3b77b54413");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '79531810-3014-4f69-ba5d-aa3b77b54413' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b6d0f849-d3a4-493f-8133-61d4436fa4c6":{"roots":{"references":[{"attributes":{"plot":{"id":"a672ebd4-df30-4414-8141-4451da99d3f4","subtype":"Figure","type":"Plot"}},"id":"761e1a0d-88c8-4e3b-b9c3-386a0a46cf3a","type":"PanTool"},{"attributes":{"formatter":{"id":"47cc2999-4580-4cc3-8e95-fe21c8b0ba29","type":"BasicTickFormatter"},"plot":{"id":"a672ebd4-df30-4414-8141-4451da99d3f4","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c678c22-1832-43e9-b60d-a93ab4f495ac","type":"BasicTicker"}},"id":"66b9a75f-44b1-4e3e-a974-f991aeaed27b","type":"LinearAxis"},{"attributes":{"below":[{"id":"987cc8a9-86c5-4aee-b649-f72cea706a60","type":"LinearAxis"}],"left":[{"id":"66b9a75f-44b1-4e3e-a974-f991aeaed27b","type":"LinearAxis"}],"renderers":[{"id":"987cc8a9-86c5-4aee-b649-f72cea706a60","type":"LinearAxis"},{"id":"8bb2dc9e-f895-49d3-9329-c9554363b76a","type":"Grid"},{"id":"66b9a75f-44b1-4e3e-a974-f991aeaed27b","type":"LinearAxis"},{"id":"e2ce8358-04ce-4dc7-94f8-8afd5676c0f4","type":"Grid"},{"id":"8924decc-56c5
...)]
# WARNING:/home/foliveira/miniconda3/envs/quicklook/lib/python3.5/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: bar:0.2] [range:y_range] [first_value: bar:0.2] [renderer: Figure(id='1d588d04-175c-4779-94ff-145b69fb6e9e', ...)]
# WARNING:/home/foliveira/miniconda3/envs/quicklook/lib/python3.5/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: bar:0.2] [range:y_range] [first_value: bar:0.2] [renderer: Figure(id='7b766269-cbfb-4915-8582-b41cff6d28b4', ...)]

# %%
from bokeh.layouts import row
#from bokeh.plotting import figure, show#, output_file

factors = ["a", "b", "c", "d", "e", "f", "g", "h"]
x =  [50, 40, 65, 10, 25, 37, 80, 60]

dot = figure(title="Categorical Dot Plot", tools="", toolbar_location=None,
            y_range=factors, x_range=[0,100])

dot.segment(0, factors, x, factors, line_width=2, line_color="green", )
dot.circle(x, factors, size=15, fill_color="orange", line_color="green", line_width=3, )

factors = ["foo 123", "bar:0.2", "baz-10"]
x = ["foo 123", "foo 123", "foo 123", "bar:0.2", "bar:0.2", "bar:0.2", "baz-10",  "baz-10",  "baz-10"]
y = ["foo 123", "bar:0.2", "baz-10",  "foo 123", "bar:0.2", "baz-10",  "foo 123", "bar:0.2", "baz-10"]
colors = [
    "#0B486B", "#79BD9A", "#CFF09E",
    "#79BD9A", "#0B486B", "#79BD9A",
    "#CFF09E", "#79BD9A", "#0B486B"
]

hm = figure(title="Categorical Heatmap", tools="hover", toolbar_location=None,
            x_range=factors, y_range=factors)

# %%
import bokeh.plotting as bp
def make_plot(mapper, title):
    mapper.low_color = 'blue' # cor abaixo de low no range do LinearColorMapper
    mapper.high_color = 'red' # 
    p = figure(toolbar_location=None, tools='', title=title)
    color_bar = ColorBar(color_mapper=mapper, location=(0, 0))
    p.circle(
        x='x', y='y',
        fill_color={'field': 'x', 'transform': mapper}, line_color=None,
        source=source
    )

# %%
import bokeh.palettes as bp
import matplotlib.pyplot as plt
import matplotlib.cm as cm

cmap_all = bp.__palettes__
#def rgb2hex(m):
#    return'#%02x%02x%02x' % (m)

from matplotlib.colors import rgb2hex
colormap =cm.get_cmap("nipy_spectral") #choose any matplotlib colormap here
bokehpalette = [rgb2hex(m) for m in colormap(np.arange(colormap.N))]

# %%
import numpy as np
from bokeh.io import show
from bokeh.layouts import gridplot
from bokeh.models import (
    ColumnDataSource,
    ColorBar,
    LinearColorMapper,
    LogColorMapper,
)
from bokeh.palettes import Viridis3, Viridis256
from bokeh.palettes import Category10_10,Accent8,BuPu5,Colorblind3
from bokeh.plotting import figure
N = 1000
x = np.random.random(N) * 140 - 20
y = np.random.normal(size=N) * 2 + 5

source = ColumnDataSource(dict(x=x, y=y))
opts = dict(x='x', line_color=None, source=source)

cmap_list = [Category10_10,Accent8,BuPu5,Colorblind3]
def make_plot(mapper, title):
    mapper.low_color = 'blue' # cor abaixo de low no range do LinearColorMapper
    mapper.high_color = 'red' # 
    p = figure(toolbar_location=None, tools='', title=title)
    color_bar = ColorBar(color_mapper=mapper, location=(0, 0))
    p.circle(
        x='x', y='y',
        fill_color={'field': 'x', 'transform': mapper}, line_color=None,
        source=source
    )

    p.add_layout(color_bar, 'right')
    return p

p1 = make_plot(LinearColorMapper(palette=Viridis256, low=0, high=100), title='Viridis256 - Linear, low/high = blue/red')
p2 = make_plot(LogColorMapper(palette=Viridis256, low=0, high=100), title='Viridis256 - Log, low/high = blue/red')
p3 = make_plot(LinearColorMapper(palette=Viridis3, low=0, high=100), title='Viridis3 - Linear, low/high = blue/red')
p4 = make_plot(LogColorMapper(palette=bokehpalette, low=0, high=100), title='Viridis3 - Log, low/high =, blue/red')

show(gridplot([p1, p2, p3, p4], ncols=2, plot_width=400, plot_height=300, toolbar_location=None))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3e66604f-312e-41b6-9663-886f375eb187"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("
subtype":"Figure","type":"Plot"},"ticker":{"id":"c7adecf0-cc73-409d-a5e7-7b4b3f2d2722","type":"BasicTicker"}},"id":"a1ffde6a-ffe2-440c-a1e8-a246c4f9edf4","type":"LinearAxis"},{"attributes":{"fill_color":{"field":"x","transform":{"id":"d1036102-7576-4cb1-8a56-443c9f09efbf","type":"LinearColorMapper"}},"line_color":{"value":null},"x":{"field":"x"},"y":{"field":"y"}},"id":"b1cb91ab-c165-4994-a708-135251062c06","type":"Circle"},{"attributes":{"children":[{"id":"c9d06a23-d73e-4bea-b230-bd054ab57b2a","type":"Row"},{"id":"a1a2f66c-8815-449a-8975-d855df6f470a","type":"Row"}]},"id":"18543830-5826-4e70-8cbc-e37da3afb352","type":"Column"},{"attributes":{"plot":null,"text":"Viridis256 - Log, low/high = blue/red"},"id":"df8bb7cf-f120-4698-a2e7-7f862ac3cf45","type":"Title"},{"attributes":{"callback":null},"id":"918b0d3b-33f3-42f7-b508-aa0426c84708","type":"DataRange1d"},{"attributes":{"formatter":{"id":"43c26522-9c1b-469c-a590-37e408adc3ce","type":"BasicTickFormatter"},"plot":{"id":"6d4619f7-a7fd-4367-9597-2009a2abccb9","subtype":"Figure","type":"Plot"},"ticker":{"id":"49905dc ...

# %%
import numpy as np

from bokeh.io import show
from bokeh.layouts import gridplot
from bokeh.models import (
    ColumnDataSource,
    ColorBar,
    LinearColorMapper,
    LogColorMapper,
)

from bokeh.palettes import *
from bokeh.plotting import figure

x = np.random.random(800) * 140 - 20
y = np.random.normal(size=800) * 2 + 5


source = ColumnDataSource(dict(x=x, y=y))
opts = dict(x='x', line_color=None, source=source)

p=[]
lista  = range(98,104 )
#lista.append(range(120,250,20))
print (lista)
for i in range(98,108 ):
    p0 = make_plot(LinearColorMapper(palette=cmap_all[i], low=-20, high=120), title=cmap_all[i])
    p.append(p0)
    
show(gridplot(p, ncols=2, plot_width=400, plot_height=300, toolbar_location=None))
# Out:
# range(98, 104)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c7e7c62f-7306-4a5f-8dc2-f6cffe03a579"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c7e7c62f-7306-4a5f-8dc2-f6cffe03a579").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c7e7c62f-7306-4a5f-8dc2-f6cffe03a579");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c7e7c62f-7306-4a5f-8dc2-f6cffe03a579' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"010209fe-adea-42fd-8ceb-7f257d3a5963":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto"},"id":"b27e6996-8f07-4678-a390-2b9b693c8224","type":"Toolbar"},{"attributes":{"plot":null,"text":"Dark2_3"},"id":"678776bd-493f-4eff-9515-996f93e2c34b","type":"Title"},{"attributes":{},"id":"43c845c9-3933-4127-98ba-6ad086b06778","type":"BasicTickFormatter"},{"attributes":{"color_mapper":{"id":"e63eed84-9770-4ce1-8c44-893c2e3a6b71","type":"LinearColorMapper"},"formatter":{"id":"7a7d17f5-2682-4213-b38b-9acfeccd3280","type":"BasicTickFormatter"},"location":[0,0],"plot":{"id":"9c76c199-958e-4fef-9fd2-cf86173c66ab","subtype":"Figure","type":"Plot"},"ticker":{"id":"1d9de922-e052-4ef1-be68-55facaeb09f3","type":"BasicTicker"}},"id":"0fa22e6f-6716-4a64-a88c-90bede0eb903","type":"ColorBar"},{"attributes":{"data_source":{"id":"a834d172-0714-4f29-85ee-9a654a74153a","type":"ColumnDataSource"},"glyph":{"id":"80ea09e0-f91b-44cc-8ea5-e310fe0752ca","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"4df97702-71e9-4be7-9047-8e21a22e14e7","type":"Circle"},"selection_glyph":null},"id":"31ac5c6e-dd6d-42fc-a2fe-af8871c4247c","type":"GlyphRenderer"},{"attributes":{},"id":"eccd8c42-85d4-477e-a072-428f977c8f73","type":"BasicTicker"},{"attributes":{"high":120,"high_color":"red","low":-20,"low_color":"blue","palette":["#0072B2","#E69F00","#F0E442","#009E73","#56B4E9","#D55E00","#CC79A7","#000000"]},"id":"7e041959-3bde-4461-9fc0-a6806e0a2376","type":"LinearColorMapper"},{"attributes":{"color_mapper":{"id":"0aba5d47-d321-473c-b312-1645fd2deeb7","type":"LinearColorMapper"},"formatter":{"id":"c036f5c2-d79f-4863-add8-42291e999ed6","type":"BasicTickFormatter"},"location":[0,0],"plot":{"id":"1d4c37b7-ad73-4e9f-82aa-562e7479c21d","subtype":"Figure","type":"Plot"},"ticker":{"id":"4cad3ec8-c913-4055-a9f4-5519ed968b78","type":"BasicTicker"}},"id":"55a32d5a-daa6-4bab-ac2c-8f33375d4fd1","type":"ColorBar"},{"attributes":{"data_source":{"id":"a834d172-0714-4f29-85ee-9a654a74153a","type":"ColumnDataSource"},"glyph":{"id":"28f49779-1ef9-4335-8025-4bf9aaab5a8d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"d1645f36-8c36-45bd-9764-e342464ee751","type":"Circle"},"selection_glyph":null},"id":"7bf054cf-e717-4966-9981-b5b4105b2113","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"ea24e1e7-7238-4707-8a67-605fb0d370c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"50da57ed-25eb-4391-8b38-09a8f722ce55","type":"BasicTicker"}},"id":"a65132ae-448a-42e0-aea9-f81f2dc3b13d","type":"Grid"},{"attributes":{"plot":null,"text":"Colorblind5"},"id":"b60d1903-afd3-4452-b484-30ce38f3f277","type":"Title"},{"attributes":{"below":[{"id":"cdc30a22-800a-421c-898b-dec1e4558ef8","type":"LinearAxis"}],"left":[{"id":"5d7e3a82-6cae-440d-8fa4-8406adac128f","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"cdc30a22-800a-421c-898b-dec1e4558ef8","type":"LinearAxis"},{"id":"8435f9e9-7a0e-42e2-95bf-427a7f7583a9","type":"Grid"},{"id":"5d7e3a82-6cae-440d-8fa4-8406adac128f","type":"LinearAxis"},{"id":"538c4a96-1e20-45f8-abd7-fe1d49f62cf5","type":"Grid"},{"id":"27e63e8e-b06d-4651-83f1-c93d27af6cbd","type":"GlyphRenderer"},{"id":"2f2b3061-f580-4245-bef2-602025ae8db8","type":"ColorBar"}],"right":[{"id":"2f2b3061-f580-4245-bef2-602025ae8db8","type":"ColorBar"}],"title":{"id":"50cfba85-a80c-45c3-800f-ad4eb3571f1f","type":"Title"},"tool_events":{"id":"4916bb7f-7d6b-48cc-92d1-f2c339792955","type":"ToolEvents"},"toolbar":{"id":"0c0dc4be-da03-426b-989a-478661b8d4c9","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"d77a28fa-dc79-43bf-a59f-94be03398813","type":"DataRange1d"},"y_range":{"id":"740082ce-f395-4419-acf4-1859e9caf99e","type":"DataRange1d"}},"id":"d225ed10-909a-4ac9-8684-b06fd9788673","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"f ...

# %%
cmap_all[98:120]
# Out:
# ['Colorblind3',
#  'Colorblind4',
#  'Colorblind5',
#  'Colorblind6',
#  'Colorblind7',
#  'Colorblind8',
#  'Dark2_3',
#  'Dark2_4',
#  'Dark2_5',
#  'Dark2_6',
#  'Dark2_7',
#  'Dark2_8',
#  'GnBu3',
#  'GnBu4',
#  'GnBu5',
#  'GnBu6',
#  'GnBu7',
#  'GnBu8',
#  'GnBu9',
#  'Greens3',
#  'Greens4',
#  'Greens5']
