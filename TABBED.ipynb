# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models.widgets import Panel, Tabs
from bokeh.layouts import row
from bokeh.io import curdoc
curdoc().clear()
# output to static HTML file
output_notebook()
p1 = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p1.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)

p2 = figure(plot_width=400, plot_height=400, y_axis_type='log')
p2.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)

# show the results


# Create tab1 from plot p1: tab1
tab1 = Panel(child=p1, title='Latin America')

# Create tab2 from plot p2: tab2
tab2 = Panel(child=p2, title='Africa')

l1 = Tabs(tabs=[tab1, tab2])
l2 = Tabs(tabs=[tab2, tab1])

show(l1)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6cd09f79-d0cd-449e-9f94-b5d872708a53">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c2995000-0178-4bc0-999f-1df4fb2c1d09"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c2995000-0178-4bc0-999f-1df4fb2c1d09").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c2995000-0178-4bc0-999f-1df4fb2c1d09");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c2995000-0178-4bc0-999f-1df4fb2c1d09' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6c69f6ee-aa71-400a-b306-89297484f926":{"roots":{"references":[{"attributes":{"plot":{"id":"996ee6cb-928b-4a35-9450-904ba06e827a","subtype":"Figure","type":"Plot"}},"id":"4fda2b9b-af7d-46e1-a484-36e97f539a37","type":"HelpTool"},{"attributes":{"child":{"id":"996ee6cb-928b-4a35-9450-904ba06e827a","subtype":"Figure","type":"Plot"},"title":"Africa"},"id":"88bd0965-1ba4-4acf-ba33-35d44c10b80b","type":"Panel"},{"attributes":{},"id":"b3293c01-d7c0-4b73-b14a-4781af45f4fd","type":"BasicTicker"},{"attributes":{"ticker":null},"id":"bfa56587-e66b-435e-add4-570bd9ab5511","type":"LogTickFormatter"},{"attributes":{"plot":{"id":"996ee6cb-928b-4a35-9450-904ba06e827a","subtype":"Figure","type":"Plot"}},"id":"c9236b6d-ee8f-4f34-b850-1e1f7def1519","type":"WheelZoomTool"},{"attributes":{},"id":"1f1be4af-c552-4c0e-8912-d4dbcf70a384","type":"BasicTicker"},{"attributes":{"plot":{"id":"996ee6cb-928b-4a35-9450-904ba06e827a","subtype":"Figure","type":"Plot"}},"id":"5e3f7f9c-eb70-4a5e-aa86-a4ff2b0a6709","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6cc09470-35a7-4e57-94b7-2e6f20438c91","type":"PanTool"},{"id":"05a319b5-f1df-4c00-a0ee-0eaeb61bb361","type":"WheelZoomTool"},{"id":"780bc4e4-f586-488c-9703-f4f7effc150d","type":"BoxZoomTool"},{"id":"d75fb356-10b4-4c39-8055-d282f4e6c583","type":"SaveTool"},{"id":"0ac0e866-c3da-40ff-a12e-b3e1e69fcd75","type":"ResetTool"},{"id":"d2584c41-3540-4f6e-98c4-88217c2eed0e","type":"HelpTool"}]},"id":"bb7b3c03-5bdb-4919-a4c0-81189387bb8b","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"84b4d71b-a93a-4f78-8bee-fdde11a84376","type":"Title"},{"attributes":{},"id":"3c524835-2de5-4e95-9d8d-58645b701112","type":"ToolEvents"},{"attributes":{"child":{"id":"dfbdce5b-32e8-4b91-bdfc-8672f3af4558","subtype":"Figure","type":"Plot"},"title":"Latin America"},"id":"ead69c4c-9ad7-4a03-bae9-1b3ae570f338","type":"Panel"},{"attributes":{"data_source":{"id":"defb7461-dafc-44be-a76d-a91d49c620b6","type":"ColumnDataSource"},"glyph":{"id":"0507eefb-54c6-4c18-8253-19458ac4cb27","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"f9484704-b5f1-4eb3-9763-ba5900ae891f","type":"Circle"},"selection_glyph":null},"id":"11c79fe4-bfe6-4feb-8b72-541c79ce937d","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"d9d5b5ad-1236-4c4a-aa19-c2aab1295d81","type":"BoxAnnotation"},"plot":{"id":"996ee6cb-928b-4a35-9450-904ba06e827a","subtype":"Figure","type":"Plot"}},"id":"459f3aa8-936c-4f95-a842-20be2f12a6a4","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"c4f252b3-5d2b-4890-8790-7d6243c7c1f4","type":"BasicTickFormatter"},"plot":{"id":"dfbdce5b-32e8-4b91-bdfc-8672f3af4558","subtype":"Figure","type":"Plot"},"ticker":{"id":"b3293c01-d7c0-4b73-b14a-4781af45f4fd","type":"BasicTicker"}},"id":"09c9fd83-4406-4e1c-9dc8-8c517d1cb594","type":"LinearAxis"},{"attributes":{"below":[{"id":"6fed68a2-15ea-4f46-b76b-8397c848c4a1","type":"LinearAxis"}],"left":[{"id":"b0ec4564-559d-4645-ae87-a952414b1953","type":"LogAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"6fed68a2-15ea-4f46-b76b-8397c848c4a1","type":"LinearAxis"},{"id":"1012769b-3887-40dd-a4fe-444730a22c6f","type":"Grid"},{"id":"b0ec4564-559d-4645-ae87-a952414b1953","type":"LogAxis"},{"id":"6eaf9f33-d3a1-4fc9-b288-002e5cf52f14","type":"Grid"},{"id":"d9d5b5ad-1236-4c4a-aa19-c2aab1295d81","type":"BoxAnnotation"},{"id":"11c79fe4-bfe6-4feb-8b72-541c79ce937d","type":"GlyphRenderer"}],"title":{"id":"e0fafbfe-be01-4f17-9609-89379300ed68","type":"Title"},"tool_events":{"id":"d89ae74e-6c96-4564-a6e3-14ce54fc9ba2","type":"ToolEvents"},"toolbar":{"id":"4e3efc16-6873-43fa-a121-27ea9b687973","type":"Toolbar"},"x_range":{"id":"45af3f30-3ccc-42e0-aa23-4cb6dfa7cf7a","type":"DataRange1d"},"y_mapper_type":"log","y_range":{"id":"fec9ffca-35cb-4688-9f0a-12df0fb86dfb","type":"DataRange1d"}},"id":"996ee6cb-928b-4a35-9450-904ba06e827a","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"i ...

# %% [markdown]
# # teste 2

# %%
# Perform necessary imports
from bokeh.models import ColumnDataSource, Select
from bokeh.io import output_file
# Create ColumnDataSource: source
source = ColumnDataSource(data={
    'x' : [2,5,6],
    'y' : [-1,-2,-3]
})

# Create a new plot: plot
plot = figure()

# Add circles to the plot
plot.circle('x', 'y', source=source, size=20)

# Define a callback function: update_plot
def update_plot(attr, old, new):
    # If the new Selection is 'female_literacy', update 'y' to female_literacy
    if new == 'female_literacy': 
        source.data = {
            'x' : [2,5,6],
            'y' : [1,2,3]
        }
    # Else, update 'y' to population
    else:
        source.data = {
            'x' : [1,2,3],
            'y' : [1,20,-3]
        }

# Create a dropdown Select widget: select    
select = Select(title="distribution", options=['female_literacy', 'population'], value='female_literacy')

# Attach the update_plot callback to the 'value' property of select
select.on_change('value', update_plot)

# Create layout and add to current document
layout = row(select, plot)
curdoc().add_root(layout)
show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3a27b47c-7e05-454b-9871-3b09292891f5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3a27b47c-7e05-454b-9871-3b09292891f5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3a27b47c-7e05-454b-9871-3b09292891f5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3a27b47c-7e05-454b-9871-3b09292891f5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1fac5e67-e598-4ebf-b05d-981580869daf":{"roots":{"references":[{"attributes":{},"id":"3ee157ed-d0ea-40df-a3ed-9ee727417d6d","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":
subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto" ...

# %%
import numpy as np
import pandas as pd
from bokeh.layouts import row, widgetbox
from bokeh.models import CustomJS, Slider, Select
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.io import push_notebook, output_notebook, curdoc
from bokeh.client import push_session
output_notebook()

#create sample pandaframe to work with, this will store the actual data
a = np.arange(50).reshape((5,10))
labels = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"]
val_a = pd.DataFrame(a, columns=labels )

# Here is a dict of some keys that I want to be able to pick from for plotting
axis_map = {
    "A": "A",
    "B": "B",
    "C": "C"
}

#This is to update during the callback
code = ''' var data = source.data;
           var value1 = val1.value;
           var value2 = val2.value;
           var original_data = original_source.data
           // get data corresponding to selection
           x = original_data[value1];
           y = original_data[value2];
           data['x'] = x;
           data['y'] = y;
           source.trigger('change');
           // set axis labels
           x_axis.axis_label = value1
           y_axis.axis_label = value2
            '''
source = ColumnDataSource(data=dict(x=val_a['A'], y=val_a['B']))
original_source = ColumnDataSource(data=val_a.to_dict(orient='list'))


#plot the figures
plot = figure(plot_width=400, plot_height=400)
plot.circle(x= "x",y="y", source=source, line_width=3, line_alpha=0.6)


callback = CustomJS(args=dict(source=source, original_source = original_source, x_axis=plot.xaxis[0],y_axis=plot.yaxis[0]), code=code)

#Create two select widgets to pick the features of interest 
x_axis = Select(title="X Axis", options=sorted(axis_map.keys()), value="A", callback = callback)
callback.args["val1"] = x_axis

y_axis = Select(title="Y Axis", options=sorted(axis_map.keys()), value="B", callback = callback)
callback.args["val2"] = y_axis

plot.xaxis[0].axis_label = 'A'
plot.yaxis[0].axis_label = 'B'

#Display the graph in a jupyter notebook
layout = row(plot, x_axis, y_axis)
show(layout, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="271cfd55-e45b-4567-8562-0c77aa8dd345">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5abde06e-18b7-4860-8499-5609d1db3125"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5abde06e-18b7-4860-8499-5609d1db3125").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("538e50df-6c0f-4969-968a-70f1d1b055f0", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5abde06e-18b7-4860-8499-5609d1db3125");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5abde06e-18b7-4860-8499-5609d1db3125' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c13fa2fa-f935-4fc9-9666-5049ae3ba1b9":{"roots":{"references":[{"attributes":{"args":{"original_source":{"id":"edab3315-0bc7-4744-906f-e0ac486b7d73","type":"ColumnDataSource"},"source":{"id":"6696cb30-016f-49b2-b089-8ab40ce1a37c","type":"ColumnDataSource"},"val1":{"id":"30c7419a-6421-4c44-84b2-2a73d66de625","type":"Select"},"val2":{"id":"3fcb05e7-29e8-459b-80f5-322bf178818a","type":"Select"},"x_axis":{"id":"000e7698-2391-46a0-97ab-539ff81a7041","type":"LinearAxis"},"y_axis":{"id":"ac323b14-1a31-44a7-8d8e-7b3e4402c17c","type":"LinearAxis"}},"code":" var data = source.data;\n           var value1 = val1.value;\n           var value2 = val2.value;\n           var original_data = original_source.data\n           // get data corresponding to selection\n           x = original_data[value1];\n           y = original_data[value2];\n           data['x'] = x;\n           data['y'] = y;\n           source.trigger('change');\n           // set axis labels\n           x_axis.axis_label = value1\n           y_axis.axis_label = value2\n            "},"id":"fc90282a-e756-4167-b044-6e6ee92333f9","type":"CustomJS"},{"attributes":{"children":[{"id":"b08c16f7-b76c-4f4e-9e20-a3f5418881fb","subtype":"Figure","type":"Plot"},{"id":"b43a70ce-fe9c-4a88-815b-6188cd350a58","type":"WidgetBox"},{"id":"76e5a082-b583-45cd-9ea2-90f277a80141","type":"WidgetBox"}]},"id":"cbc72f43-7fda-400b-adb4-2b902f111c9e","type":"Row"},{"attributes":{"axis_label":"A","formatter":{"id":"fc2c47ab-8266-42b7-b2d4-6cd7ee707c4c","type":"BasicTickFormatter"},"plot":{"id":"b08c16f7-b76c-4f4e-9e20-a3f5418881fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"103d683f-5136-4095-ac89-4f031695b829","type":"BasicTicker"}},"id":"000e7698-2391-46a0-97ab-539ff81a7041","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bf396077-9dc6-4077-8e02-18e9e549d73e","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"b08c16f7-b76c-4f4e-9e20-a3f5418881fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"103d683f-5136-4095-ac89-4f031695b829","type":"BasicTicker"}},"id":"08ba5566-3d36-4992-8718-db1da60b0fef","type":"Grid"},{"attributes":{"below":[{"id":"000e7698-2391-46a0-97ab-539ff81a7041","type":"LinearAxis"}],"left":[{"id":"ac323b14-1a31-44a7-8d8e-7b3e4402c17c","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"000e7698-2391-46a0-97ab-539ff81a7041","type":"LinearAxis"},{"id":"08ba5566-3d36-4992-8718-db1da60b0fef","type":"Grid"},{"id":"ac323b14-1a31-44a7-8d8e-7b3e4402c17c","type":"LinearAxis"},{"id":"1d288966-9375-400a-973f-2cebe11f6afc","type":"Grid"},{"id":"bf396077-9dc6-4077-8e02-18e9e549d73e","type":"BoxAnnotation"},{"id":"24f6c96d-6b0c-4528-b0d9-07c76180cfed","type":"GlyphRenderer"}],"title":{"id":"ef276088-19c1-4560-a693-3848dc2fa0f4","type":"Title"},"tool_events":{"id":"57635398-ef9e-4af9-b071-f0ca285a07a2","type":"ToolEvents"},"toolbar":{"id":"372c4f3b-25c5-4f4d-b62a-d67cf2198645","type":"Toolbar"},"x_range":{"id":"f3103648-04de-4a44-b767-0c9ee4d9c9fe","type":"DataRange1d"},"y_range":{"id":"28625b4f-a15b-4136-8b77-5120cb0b523f","type":"DataRange1d"}},"id":"b08c16f7-b76c-4f4e-9e20-a3f5418881fb","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"28625b4f-a15b-4136-8b77-5120cb0b523f","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"c90d903b-b84b-4fc5-b197-2079fe71bdd7","type":"Circle"},{"attributes":{"plot":{"id":"b08c16f7-b76c-4f4e-9e20-a3f5418881fb","subtype":"Figure","type":"Plot"}},"id":"49476ade-0dcc-423f-ab8d-e78a3be24f2e","type":"PanTool"},{"attribut ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>
