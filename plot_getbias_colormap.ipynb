# %%
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show
from bokeh.models import (LinearColorMapper ,    ColorBar)
from bokeh.palettes import (Category10_10,Accent8,BuPu5,
                    Colorblind3,RdYlBu11, YlGnBu9,Spectral3, 
                    Plasma256, RdYlBu,Colorblind, Viridis3, Viridis256)
from bokeh.io import output_notebook
import numpy as np

# %%
# =============================================
# THIS comes from INTERFACE
#
selected_exposure = '00000003'# args['exposure']
selected_arm = 'r' # args['arm']
selected_spectrograph =  4 # args['spectrograph']

# =============================================
# THIS comes from QLF.CFG
#
night = '20190101'

# ============================================
#  THIS READ yaml files
#
from scalar_metrics_v02 import LoadMetrics

cam = selected_arm+str(selected_spectrograph)
exp = selected_exposure # intentionaly redundant
lm = LoadMetrics(cam, exp, night);
metrics, tests  = lm.metrics, lm.tests 

# =============================================
# THIS is only to simplify the code understanding
#
countpix  = metrics['countpix']
getbias   = metrics['getbias']
getrms    = metrics['getrms']
xwsigma   = metrics['xwsigma']
countbins = metrics['countbins']
integ     = metrics['integ']
skycont   = metrics['skycont']
skypeak   = metrics['skypeak']
skyresid  = metrics['skyresid']
snr       = metrics['snr']
# Out:
# countpix loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-countpix-r4-00000003.yaml
# getbias loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-getbias-r4-00000003.yaml
# getrms loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-getrms-r4-00000003.yaml
# xwsigma loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-xwsigma-r4-00000003.yaml
# countbins loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-countbins-r4-00000003.yaml
# integ loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-integ-r4-00000003.yaml
# skycont loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-skycont-r4-00000003.yaml
# skypeak loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-skypeak-r4-00000003.yaml
# skyresid loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-skyresid-r4-00000003.yaml
# snr loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-snr-r4-00000003.yaml

# %% [markdown]
# ### Get Bias

# %%
# Get Bias
name = 'BIAS_AMP'
metr = getbias

dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']

mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

hover = HoverTool(tooltips=[
         ("counts", "@z"),
         ("AMP", "@amp"),
         ])

p = figure(title="AMP COUNTS", tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b4212ada-5dec-4a88-98a9-d0ec2ac69e12">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5c163740-e37e-4015-b445-0d1252153e31"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5c163740-e37e-4015-b445-0d1252153e31").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5c163740-e37e-4015-b445-0d1252153e31");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5c163740-e37e-4015-b445-0d1252153e31' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e1e4ee77-46ef-4e81-a340-50ba0bfc7c67":{"roots":{"references":[{"attributes":{"text":{"field":"amp"},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"field":"y_offset1"}},"id":"81ac7960-11c6-4077-9224-50e2163587c8","type":"Text"},{"attributes":{"callback":null,"plot":{"id":"d316077f-6c3c-4d3a-b0b4-bb69472346bd","subtype":"Figure","type":"Plot"},"tooltips":[["counts","@z"],["AMP","@amp"]]},"id":"7c2cf06f-af0c-449f-bd06-0017078e4ef0","type":"HoverTool"},{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"223a5b7e-674e-4768-bc79-2867f0c337c3","type":"Text"},{"attributes":{"formatter":{"id":"2aceb683-8ddb-4c01-8e36-bc3f24ea60e0","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"d316077f-6c3c-4d3a-b0b4-bb69472346bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"84c5e649-e96b-421e-b949-0f7aa84867cd","type":"BasicTicker"}},"id":"dd26b806-cfdc-49ae-9583-f833629e09fa","type":"LinearAxis"},{"attributes":{},"id":"0e133023-4949-4f03-a478-32f787918fd6","type":"ToolEvents"},{"attributes":{"text":{"field":"amp"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"field":"y_offset1"}},"id":"15ccbc73-b30a-4711-b861-7b45b3c64188","type":"Text"},{"attributes":{"below":[{"id":"dd26b806-cfdc-49ae-9583-f833629e09fa","type":"LinearAxis"}],"left":[{"id":"c4608739-ad1d-4669-8f25-e26303888d87","type":"LinearAxis"},{"id":"224fbd7c-15ce-4bed-8149-4aa6cd35c5f3","type":"ColorBar"}],"outline_line_color":{"value":null},"plot_height":400,"plot_width":400,"renderers":[{"id":"dd26b806-cfdc-49ae-9583-f833629e09fa","type":"LinearAxis"},{"id":"b130035c-cb3e-4f31-adad-561db705e85d","type":"Grid"},{"id":"c4608739-ad1d-4669-8f25-e26303888d87","type":"LinearAxis"},{"id":"e1611e0b-0b9e-44ad-9eef-355af8df47db","type":"Grid"},{"id":"78239e72-a544-43bd-bd99-f0273e95ce75","type":"GlyphRenderer"},{"id":"8bb03fae-66f0-464a-9f37-27ee5c61150e","type":"GlyphRenderer"},{"id":"a2e5a368-9563-4690-b33b-d534c8c6789f","type":"GlyphRenderer"},{"id":"224fbd7c-15ce-4bed-8149-4aa6cd35c5f3","type":"ColorBar"}],"title":{"id":"29b02ba8-5bdb-4a82-93d0-4c7ed4d9ce7f","type":"Title"},"tool_events":{"id":"0e133023-4949-4f03-a478-32f787918fd6","type":"ToolEvents"},"toolbar":{"id":"8c076e57-5347-4b73-aef3-06c637e933c5","type":"Toolbar"},"x_range":{"id":"c2827dc4-f66d-4044-b116-06bb1464f77d","type":"Range1d"},"y_range":{"id":"8b479954-e53c-4e8f-bbfe-3528ad5f5028","type":"Range1d"}},"id":"d316077f-6c3c-4d3a-b0b4-bb69472346bd","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"d316077f-6c3c-4d3a-b0b4-bb69472346bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"783d2778-cd73-4912-bce1-391aaa2e8646","type":"BasicTicker"}},"id":"e1611e0b-0b9e-44ad-9eef-355af8df47db","type":"Grid"},{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"e8b11e23-9c21-4fbf-94b2-b7fe7a8bb727","type":"Text"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"field":"z","transform":{"id":"83ea211c-fa02-4dd5-bba9-4ae585f65241","type":"LinearColorMapper"}},"height":{"units":"data","value":0.98},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b636d98-8a11-4981-8513-8e2ff4be4fda","type":"Rect"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C" ...

# %%
# Out:
# dict_keys(['DATA5SIG', 'BIAS_AMP', 'DIFF3SIG', 'DIFF1SIG', 'BIASDIFF_ERR', 'MEANBIAS_ROW', 'DIFF2SIG', 'BIAS'])

# %% [markdown]
# ### Countpix

# %%
name = 'NPIX_LOW_AMP'
metr = countpix

# Get Bias
dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

hover = HoverTool(tooltips=[
         ("counts", "@z"),
         ("AMP", "@amp"),
         ])

p = figure(title="AMP COUNTS", tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fbd4de76-0d52-40ba-87e0-225aff8fafad">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a2229488-f9d1-4e41-bfec-3c97ab2c6c5a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a2229488-f9d1-4e41-bfec-3c97ab2c6c5a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a2229488-f9d1-4e41-bfec-3c97ab2c6c5a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a2229488-f9d1-4e41-bfec-3c97ab2c6c5a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4b9a56bc-f96f-48a9-ae2c-17038b3e4a5d":{"roots":{"references":[{"attributes":{"text":{"field":"amp"},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"field":"y_offset1"}},"id":"9b5ff115-2619-45af-be9e-7abb53aed2c5","type":"Text"},{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"19b18663-8190-4c69-80c9-bc51300d2244","type":"Text"},{"attributes":{},"id":"4aea8d9f-743c-4cf4-b547-5763645ca261","type":"BasicTicker"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"8f03507d-cfed-4028-8b06-9fd0f8301003","subtype":"Figure","type":"Plot"},"ticker":{"id":"4aea8d9f-743c-4cf4-b547-5763645ca261","type":"BasicTicker"}},"id":"65ccd133-93ef-4100-8924-924d2d51ae38","type":"Grid"},{"attributes":{"callback":null,"plot":{"id":"8f03507d-cfed-4028-8b06-9fd0f8301003","subtype":"Figure","type":"Plot"},"tooltips":[["counts","@z"],["AMP","@amp"]]},"id":"205d6d68-7b4c-404c-84fa-4ede75f0494f","type":"HoverTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"205d6d68-7b4c-404c-84fa-4ede75f0494f","type":"HoverTool"}]},"id":"e30b60e7-49e3-4af0-af39-b37e270ae628","type":"Toolbar"},{"attributes":{},"id":"70f18d4d-8250-4551-bad1-e419b2d44ade","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.98},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"e77fa714-50cf-4f8e-b78d-15f1a1384656","type":"Rect"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"field":"z","transform":{"id":"0e380220-615f-49d3-94e1-a9be9fd12c24","type":"LinearColorMapper"}},"height":{"units":"data","value":0.98},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"00e94377-1490-495e-a008-8d96ecc1faa1","type":"Rect"},{"attributes":{},"id":"492e2516-5b36-4150-924b-cee477d8d039","type":"ToolEvents"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"8f03507d-cfed-4028-8b06-9fd0f8301003","subtype":"Figure","type":"Plot"},"ticker":{"id":"cf7f6860-a10c-4f1e-9848-495420b46816","type":"BasicTicker"}},"id":"b96f8048-0ffd-4971-95b5-8657d32aad5c","type":"Grid"},{"attributes":{},"id":"c7f22009-866f-42fc-b773-edc8e97410eb","type":"BasicTicker"},{"attributes":{"data_source":{"id":"69b3ce18-bd21-4878-bfc1-6ce8c4131081","type":"ColumnDataSource"},"glyph":{"id":"9b5ff115-2619-45af-be9e-7abb53aed2c5","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"67780a5e-8d92-495d-a357-a774639a0917","type":"Text"},"selection_glyph":null},"id":"598b9cf1-9fc1-409b-be52-573bb8ed18b5","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"ff4cda11-7215-4ef3-90e2-c3d1cc1af819","type":"Range1d"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"36f3c129-aeac-4370-b5c8-4d06b35ceda7","type":"Range1d"},{"attributes":{"text":{"field":"amp"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"field":"y_offset1"}},"id":"67780a5e-8d92-495d-a357-a774639a0917","type":"Text"},{"attributes":{"callback":null,"column_names":["y_offset1","amp","z","ztext","y_offset2","x","y"],"data":{"amp":["AMP 1","AMP 2","AMP 3","AMP 4"],"x":[0,1,0,1],"y":[1,1,0,0],"y_offset1":[1.15,1.15,0.15,0.15],"y_offset2":[0.95,0.95,-0.05,-0.05],"z":[28499,20865,68968,93923],"ztext":["2.850e+04","2.086e+04","6.897e+04","9.392e+04"]}},"id":"69b3ce18-bd21-4878-bfc1-6ce8c4131081","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"b31ad1c4-8ffe-472a-81ce-3da7d1a ...

# %% [markdown]
# ### INTEG

# %%
name = 'INTEG_AVG_AMP'
metr = integ

# Get Bias
dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

hover = HoverTool(tooltips=[
         ("counts", "@z"),
         ("AMP", "@amp"),
         ])

p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="03d41281-2418-4a4e-a1f8-4081c93ff3fa">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="673e5474-fc74-4fbf-8c5e-1fe3ac079312"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("673e5474-fc74-4fbf-8c5e-1fe3ac079312").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("673e5474-fc74-4fbf-8c5e-1fe3ac079312");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '673e5474-fc74-4fbf-8c5e-1fe3ac079312' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"37a197c6-721e-401a-99aa-eaf2b317bdd9":{"roots":{"references":[{"attributes":{"data_source":{"id":"ec7d14a4-c47f-4ad2-8379-4807ce0d334f","type":"ColumnDataSource"},"glyph":{"id":"60326a86-97ad-401d-87e3-d81cb124a69b","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"5b661db7-2e3c-40e8-8d5a-3096bf8c7a27","type":"Text"},"selection_glyph":null},"id":"82dcbd25-ed58-42b1-9fdf-ad656993cdc7","type":"GlyphRenderer"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"004db1cb-0def-460e-bbb5-4a6062b70aee","subtype":"Figure","type":"Plot"},"ticker":{"id":"02cf289a-6b39-4235-9855-f32bcb17818c","type":"BasicTicker"}},"id":"9858e98e-2ef9-4353-8c3b-1302c77a2dea","type":"Grid"},{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"5b661db7-2e3c-40e8-8d5a-3096bf8c7a27","type":"Text"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472A79","#472B7A","#472C7B","#462D7C","#462F7C","#46307D","#46317E","#45327F","#45347F","#453580","#453681","#443781","#443982","#433A83","#433B83","#433C84","#423D84","#423E85","#424085","#414186","#414286","#404387","#404487","#3F4587","#3F4788","#3E4888","#3E4989","#3D4A89","#3D4B89","#3D4C89","#3C4D8A","#3C4E8A","#3B508A","#3B518A","#3A528B","#3A538B","#39548B","#39558B","#38568B","#38578C","#37588C","#37598C","#365A8C","#365B8C","#355C8C","#355D8C","#345E8D","#345F8D","#33608D","#33618D","#32628D","#32638D","#31648D","#31658D","#31668D","#30678D","#30688D","#2F698D","#2F6A8D","#2E6B8E","#2E6C8E","#2E6D8E","#2D6E8E","#2D6F8E","#2C708E","#2C718E","#2C728E","#2B738E","#2B748E","#2A758E","#2A768E","#2A778E","#29788E","#29798E","#287A8E","#287A8E","#287B8E","#277C8E","#277D8E","#277E8E","#267F8E","#26808E","#26818E","#25828E","#25838D","#24848D","#24858D","#24868D","#23878D","#23888D","#23898D","#22898D","#228A8D","#228B8D","#218C8D","#218D8C","#218E8C","#208F8C","#20908C","#20918C","#1F928C","#1F938B","#1F948B","#1F958B","#1F968B","#1E978A","#1E988A","#1E998A","#1E998A","#1E9A89","#1E9B89","#1E9C89","#1E9D88","#1E9E88","#1E9F88","#1EA087","#1FA187","#1FA286","#1FA386","#20A485","#20A585","#21A685","#21A784","#22A784","#23A883","#23A982","#24AA82","#25AB81","#26AC81","#27AD80","#28AE7F","#29AF7F","#2AB07E","#2BB17D","#2CB17D","#2EB27C","#2FB37B","#30B47A","#32B57A","#33B679","#35B778","#36B877","#38B976","#39B976","#3BBA75","#3DBB74","#3EBC73","#40BD72","#42BE71","#44BE70","#45BF6F","#47C06E","#49C16D","#4BC26C","#4DC26B","#4FC369","#51C468","#53C567","#55C666","#57C665","#59C764","#5BC862","#5EC961","#60C960","#62CA5F","#64CB5D","#67CC5C","#69CC5B","#6BCD59","#6DCE58","#70CE56","#72CF55","#74D054","#77D052","#79D151","#7CD24F","#7ED24E","#81D34C","#83D34B","#86D449","#88D547","#8BD546","#8DD644","#90D643","#92D741","#95D73F","#97D83E","#9AD83C","#9DD93A","#9FD938","#A2DA37","#A5DA35","#A7DB33","#AADB32","#ADDC30","#AFDC2E","#B2DD2C","#B5DD2B","#B7DD29","#BADE27","#BDDE26","#BFDF24","#C2DF22","#C5DF21","#C7E01F","#CAE01E","#CDE01D","#CFE11C","#D2E11B","#D4E11A","#D7E219","#DAE218","#DCE218","#DFE318","#E1E318","#E4E318","#E7E419","#E9E419","#ECE41A","#EEE51B","#F1E51C","#F3E51E","#F6E61F","#F8E621","#FAE622","#FDE724"]},"id":"b2598ed0-e190-4abd-805d-fb417269435a","type":"LinearColorMapper"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"bfb16559-0ff0-48d2-a851-185c5e873355","type":"Range1d"},{"attributes":{"text":{"field":"amp"},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"fiel ...

# %% [markdown]
# ### SKYPEAK

# %%
name = 'SUMCOUNT_RMS_AMP'
metr = skypeak

# Get Bias
dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

hover = HoverTool(tooltips=[
         ("counts", "@z"),
         ("AMP", "@amp"),
         ])

p = figure(title="AMP COUNTS", tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c1d9d3b3-c25d-43ba-aa05-da18d56e39da">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="09905189-47d2-424a-bc12-2c4e146fc93c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("09905189-47d2-424a-bc12-2c4e146fc93c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("09905189-47d2-424a-bc12-2c4e146fc93c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '09905189-47d2-424a-bc12-2c4e146fc93c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5014fbef-0a16-4fc2-8cc6-1ee718cea842":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y_offset1","amp","z","ztext","y_offset2","x","y"],"data":{"amp":["AMP 1","AMP 2","AMP 3","AMP 4"],"x":[0,1,0,1],"y":[1,1,0,0],"y_offset1":[1.15,1.15,0.15,0.15],"y_offset2":[0.95,0.95,-0.05,-0.05],"z":["NaN",18.07457712351294,"NaN",6.845803467534718],"ztext":[" nan","1.807e+01"," nan","6.846e+00"]}},"id":"b7417b91-56bd-48fc-b90a-d61d56875707","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b7417b91-56bd-48fc-b90a-d61d56875707","type":"ColumnDataSource"},"glyph":{"id":"b7ffe9f8-6dee-4437-bb1b-e508e0641f0c","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"da56d147-c6e9-4025-ad76-13fbf4402e8f","type":"Text"},"selection_glyph":null},"id":"79a2f906-b221-4c4a-9d44-6f000705e558","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"f07f3697-24e6-4944-b998-a28d244a1fa7","type":"LinearAxis"}],"left":[{"id":"a5949a32-894b-4cee-9364-ed4d02ff6c5d","type":"LinearAxis"},{"id":"8834b920-ee84-4cda-b7e0-7cc5159c0b98","type":"ColorBar"}],"outline_line_color":{"value":null},"plot_height":400,"plot_width":400,"renderers":[{"id":"f07f3697-24e6-4944-b998-a28d244a1fa7","type":"LinearAxis"},{"id":"e90d73c9-0424-42f9-8804-ff797de4a46e","type":"Grid"},{"id":"a5949a32-894b-4cee-9364-ed4d02ff6c5d","type":"LinearAxis"},{"id":"98255615-3828-4265-bf04-3e9de9bf3559","type":"Grid"},{"id":"e9cfaade-240f-4e9b-a3d3-732179930e35","type":"GlyphRenderer"},{"id":"77b558b8-2f11-4575-a0ea-3164736b06f5","type":"GlyphRenderer"},{"id":"79a2f906-b221-4c4a-9d44-6f000705e558","type":"GlyphRenderer"},{"id":"8834b920-ee84-4cda-b7e0-7cc5159c0b98","type":"ColorBar"}],"title":{"id":"18134318-e9c8-433a-af54-4c222d01d63c","type":"Title"},"tool_events":{"id":"e204eb1e-beb2-42a3-8cf3-660d1be48e0a","type":"ToolEvents"},"toolbar":{"id":"2705fe21-6481-4ad2-bf12-9748c652c1bb","type":"Toolbar"},"x_range":{"id":"f83bd647-644b-4725-832b-86f0fa3c553f","type":"Range1d"},"y_range":{"id":"086e1b03-f2c1-40be-9606-30a76adf4225","type":"Range1d"}},"id":"83b3825a-06ae-4117-9323-0487cfdac273","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"379af5e3-7432-4dcb-835c-8c1bc8fb5d2a","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"086e1b03-f2c1-40be-9606-30a76adf4225","type":"Range1d"},{"attributes":{},"id":"67b4d937-08f8-4872-86ca-e22719d093a1","type":"BasicTicker"},{"attributes":{"text":{"field":"amp"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"field":"y_offset1"}},"id":"da56d147-c6e9-4025-ad76-13fbf4402e8f","type":"Text"},{"attributes":{},"id":"e204eb1e-beb2-42a3-8cf3-660d1be48e0a","type":"ToolEvents"},{"attributes":{"plot":null,"text":"AMP COUNTS"},"id":"18134318-e9c8-433a-af54-4c222d01d63c","type":"Title"},{"attributes":{"formatter":{"id":"379af5e3-7432-4dcb-835c-8c1bc8fb5d2a","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"83b3825a-06ae-4117-9323-0487cfdac273","subtype":"Figure","type":"Plot"},"ticker":{"id":"7b9d80ef-e0b1-4faa-b8cb-1a9f28f9c45e","type":"BasicTicker"}},"id":"f07f3697-24e6-4944-b998-a28d244a1fa7","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.98},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"3715b8f7-6d5a-446e-8550-f4a1929eb913","type":"Rect"},{"attributes":{},"id":"7b9d80ef-e0b1-4faa-b8cb-1a9f28f9c45e","type":"BasicTicker"},{"attributes":{},"id":"52b0317a-797a-4e83-8ec6-637530f5778a","type":"BasicTickFormatter"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"83b3825a-06ae-4117-9323-0487cfdac273","subtype":"Figure","type":"Plot"},"ticker":{"id": ...
