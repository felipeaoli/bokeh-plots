# %%
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show
from bokeh.models import (LinearColorMapper ,    ColorBar)
from bokeh.palettes import (Category10_10,Accent8,BuPu5,
                    Colorblind3,RdYlBu11, YlGnBu9,Spectral3, 
                    Plasma256, RdYlBu,Colorblind, Viridis3, Viridis256)
from bokeh.io import output_notebook
import numpy as np

# %%
# =============================================
# THIS comes from INTERFACE
#
selected_exposure = '00000003'# args['exposure']
selected_arm = 'r' # args['arm']
selected_spectrograph =  4 # args['spectrograph']

# =============================================
# THIS comes from QLF.CFG
#
night = '20190101'

# ============================================
#  THIS READ yaml files
#
from scalar_metrics_v02 import LoadMetrics

cam = selected_arm+str(selected_spectrograph)
exp = selected_exposure # intentionaly redundant
lm = LoadMetrics(cam, exp, night);
metrics, tests  = lm.metrics, lm.tests 

# =============================================
# THIS is only to simplify the code understanding
#
countpix  = metrics['countpix']
getbias   = metrics['getbias']
getrms    = metrics['getrms']
xwsigma   = metrics['xwsigma']
countbins = metrics['countbins']
integ     = metrics['integ']
skycont   = metrics['skycont']
skypeak   = metrics['skypeak']
skyresid  = metrics['skyresid']
snr       = metrics['snr']
# Out:
# countpix loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-countpix-r4-00000003.yaml
# getbias loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-getbias-r4-00000003.yaml
# getrms loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-getrms-r4-00000003.yaml
# xwsigma loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-xwsigma-r4-00000003.yaml
# countbins loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-countbins-r4-00000003.yaml
# integ loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-integ-r4-00000003.yaml
# skycont loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-skycont-r4-00000003.yaml
# skypeak loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-skypeak-r4-00000003.yaml
# skyresid loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-skyresid-r4-00000003.yaml
# snr loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-snr-r4-00000003.yaml

# %% [markdown]
# ### Get Bias

# %%
# Get Bias
name = 'BIAS_AMP'
metr = getbias

dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']

mapper = LinearColorMapper(palette= Viridis256)



source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

cmap_tooltip = """
    <div>
        <div>
            <span style="font-size: 12px; font-weight: bold; color: #303030;">counts: </span>
            <span style="font-size: 13px; color: #515151">@z</span>
        </div>
        <div>
            <span style="font-size: 12px; font-weight: bold; color: #303030;">AMP: </span>
            <span style="font-size: 13px; color: #515151;">@amp</span>
        </div>
    </div>
""".replace("counts:", name+":")

hover = HoverTool(tooltips=cmap_tooltip)
#[         ("counts", "@z"),
#         ("AMP", "@amp"),         ])

p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="75c3eb47-95b7-41b6-8aba-228393b990e0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8c4de935-949f-41a4-897d-3b715a06dd36"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8c4de935-949f-41a4-897d-3b715a06dd36").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8c4de935-949f-41a4-897d-3b715a06dd36");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8c4de935-949f-41a4-897d-3b715a06dd36' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"234816e2-14ea-468d-8ee0-7c9400a7d7c0":{"roots":{"references":[{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"e558dc0d-9cf3-4310-821b-d1f4d3749037","type":"Range1d"},{"attributes":{},"id":"7b15cc97-4314-451e-ba7c-b13be1400f91","type":"ToolEvents"},{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"7d23aa51-9fb6-49af-b660-91765f1ca7e5","type":"Text"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"f5a28ecd-2e34-4c95-892e-2234ca9de52a","subtype":"Figure","type":"Plot"},"ticker":{"id":"fac8a97b-49c9-4f03-82b5-97699a088d3e","type":"BasicTicker"}},"id":"a3b3f177-7709-4768-b1f2-d32e96018cde","type":"Grid"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472A79","#472B7A","#472C7B","#462D7C","#462F7C","#46307D","#46317E","#45327F","#45347F","#453580","#453681","#443781","#443982","#433A83","#433B83","#433C84","#423D84","#423E85","#424085","#414186","#414286","#404387","#404487","#3F4587","#3F4788","#3E4888","#3E4989","#3D4A89","#3D4B89","#3D4C89","#3C4D8A","#3C4E8A","#3B508A","#3B518A","#3A528B","#3A538B","#39548B","#39558B","#38568B","#38578C","#37588C","#37598C","#365A8C","#365B8C","#355C8C","#355D8C","#345E8D","#345F8D","#33608D","#33618D","#32628D","#32638D","#31648D","#31658D","#31668D","#30678D","#30688D","#2F698D","#2F6A8D","#2E6B8E","#2E6C8E","#2E6D8E","#2D6E8E","#2D6F8E","#2C708E","#2C718E","#2C728E","#2B738E","#2B748E","#2A758E","#2A768E","#2A778E","#29788E","#29798E","#287A8E","#287A8E","#287B8E","#277C8E","#277D8E","#277E8E","#267F8E","#26808E","#26818E","#25828E","#25838D","#24848D","#24858D","#24868D","#23878D","#23888D","#23898D","#22898D","#228A8D","#228B8D","#218C8D","#218D8C","#218E8C","#208F8C","#20908C","#20918C","#1F928C","#1F938B","#1F948B","#1F958B","#1F968B","#1E978A","#1E988A","#1E998A","#1E998A","#1E9A89","#1E9B89","#1E9C89","#1E9D88","#1E9E88","#1E9F88","#1EA087","#1FA187","#1FA286","#1FA386","#20A485","#20A585","#21A685","#21A784","#22A784","#23A883","#23A982","#24AA82","#25AB81","#26AC81","#27AD80","#28AE7F","#29AF7F","#2AB07E","#2BB17D","#2CB17D","#2EB27C","#2FB37B","#30B47A","#32B57A","#33B679","#35B778","#36B877","#38B976","#39B976","#3BBA75","#3DBB74","#3EBC73","#40BD72","#42BE71","#44BE70","#45BF6F","#47C06E","#49C16D","#4BC26C","#4DC26B","#4FC369","#51C468","#53C567","#55C666","#57C665","#59C764","#5BC862","#5EC961","#60C960","#62CA5F","#64CB5D","#67CC5C","#69CC5B","#6BCD59","#6DCE58","#70CE56","#72CF55","#74D054","#77D052","#79D151","#7CD24F","#7ED24E","#81D34C","#83D34B","#86D449","#88D547","#8BD546","#8DD644","#90D643","#92D741","#95D73F","#97D83E","#9AD83C","#9DD93A","#9FD938","#A2DA37","#A5DA35","#A7DB33","#AADB32","#ADDC30","#AFDC2E","#B2DD2C","#B5DD2B","#B7DD29","#BADE27","#BDDE26","#BFDF24","#C2DF22","#C5DF21","#C7E01F","#CAE01E","#CDE01D","#CFE11C","#D2E11B","#D4E11A","#D7E219","#DAE218","#DCE218","#DFE318","#E1E318","#E4E318","#E7E419","#E9E419","#ECE41A","#EEE51B","#F1E51C","#F3E51E","#F6E61F","#F8E621","#FAE622","#FDE724"]},"id":"1c0aadbe-977b-4adc-89f6-a402eb071d51","type":"LinearColorMapper"},{"attributes":{"below":[{"id":"9da283fc-1010-44d1-84ca-fc8444492611","type":"LinearAxis"}],"left":[{"id":"8cdc744e-722e-4c23-976d-af11a607d7e7","type":"LinearAxis"},{"id":"ad009c23-aa7a-491f-b0c3-11d8adcf8c12","type":"ColorBar"}],"outline_line_color":{"value":null},"plot_height":400,"plot_width":400,"renderers":[{"id":"9da283fc-1010-44d1-84ca-fc8444492611","type":"LinearAxis"},{"id":"a3b3f177-7709-4768-b1f2-d32e96018cde","type":"Grid"},{"id":"8cdc744e-722e-4c23-976d- ...

# %%
# Out:
# dict_keys(['DATA5SIG', 'BIAS_AMP', 'DIFF3SIG', 'DIFF1SIG', 'BIASDIFF_ERR', 'MEANBIAS_ROW', 'DIFF2SIG', 'BIAS'])

# %% [markdown]
# ### Countpix

# %%
name = 'NPIX_LOW_AMP'
metr = countpix

# Get Bias
dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

cmap_tooltip = """
    <div>
        <div>
            <span style="font-size: 12px; font-weight: bold; color: #303030;">counts: </span>
            <span style="font-size: 13px; color: #515151">@z</span>
        </div>
        <div>
            <span style="font-size: 12px; font-weight: bold; color: #303030;">AMP: </span>
            <span style="font-size: 13px; color: #515151;">@amp</span>
        </div>
    </div>
""".replace("counts:", name+":")

hover = HoverTool(tooltips=cmap_tooltip)


p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dac7015b-f97c-45ce-b9ba-244139557288">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="de15301f-e244-44ee-9e95-32ee29a9b8ad"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("de15301f-e244-44ee-9e95-32ee29a9b8ad").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("de15301f-e244-44ee-9e95-32ee29a9b8ad");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'de15301f-e244-44ee-9e95-32ee29a9b8ad' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"574df311-6ad0-4d58-967a-8f8c0895e045":{"roots":{"references":[{"attributes":{"text":{"field":"amp"},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"field":"y_offset1"}},"id":"e9ad87f3-4f80-4eb2-ac5c-e95c1bd6d90e","type":"Text"},{"attributes":{"data_source":{"id":"bbdda5fa-f996-4c87-a549-d82fdecfb4dc","type":"ColumnDataSource"},"glyph":{"id":"e9ad87f3-4f80-4eb2-ac5c-e95c1bd6d90e","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"f2df4681-88fc-4ff4-acaa-e0b5e194fbc0","type":"Text"},"selection_glyph":null},"id":"3b1750de-4cd5-4900-94be-cf5ca2245913","type":"GlyphRenderer"},{"attributes":{},"id":"24bf8fae-978a-4a00-a0a1-6992ae9e630d","type":"BasicTicker"},{"attributes":{},"id":"51aa7761-9ec9-4f53-89ea-1bff8e363380","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.98},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1709b18-f460-46b0-bd50-3e584f623732","type":"Rect"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"27631301-db7d-4495-b66d-dffec9a315b3","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e82f726a-2811-41c3-8b53-420f8cd1649a","type":"HoverTool"}]},"id":"c4394f74-2236-48e0-aba5-f02faa630586","type":"Toolbar"},{"attributes":{"formatter":{"id":"ea486ace-ae84-4e13-8ad4-c1a999ea5368","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"7b1471f4-7517-4107-a589-e0bf7aade208","subtype":"Figure","type":"Plot"},"ticker":{"id":"851db069-ba19-408d-9312-72bac95709d8","type":"BasicTicker"}},"id":"235720dd-90ba-46c2-83ce-df7b05ffac81","type":"LinearAxis"},{"attributes":{"callback":null,"plot":{"id":"7b1471f4-7517-4107-a589-e0bf7aade208","subtype":"Figure","type":"Plot"},"tooltips":"\n    <div>\n        <div>\n            <span style=\"font-size: 12px; font-weight: bold; color: #303030;\">NPIX_LOW_AMP: </span>\n            <span style=\"font-size: 13px; color: #515151\">@z</span>\n        </div>\n        <div>\n            <span style=\"font-size: 12px; font-weight: bold; color: #303030;\">AMP: </span>\n            <span style=\"font-size: 13px; color: #515151;\">@amp</span>\n        </div>\n    </div>\n"},"id":"e82f726a-2811-41c3-8b53-420f8cd1649a","type":"HoverTool"},{"attributes":{"formatter":{"id":"51aa7761-9ec9-4f53-89ea-1bff8e363380","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"7b1471f4-7517-4107-a589-e0bf7aade208","subtype":"Figure","type":"Plot"},"ticker":{"id":"24bf8fae-978a-4a00-a0a1-6992ae9e630d","type":"BasicTicker"}},"id":"2ca3e1b0-0f5c-4051-9797-ece9137fabe3","type":"LinearAxis"},{"attributes":{},"id":"b047d010-22f8-4535-b0fa-9c0c58b0ee53","type":"BasicTicker"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"7b1471f4-7517-4107-a589-e0bf7aade208","subtype":"Figure","type":"Plot"},"ticker":{"id":"24bf8fae-978a-4a00-a0a1-6992ae9e630d","type":"BasicTicker"}},"id":"e5f20e30-a17e-45e5-b9e6-61fc18a65bd1","type":"Grid"},{"attributes":{},"id":"ea486ace-ae84-4e13-8ad4-c1a999ea5368","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"bbdda5fa-f996-4c87-a549-d82fdecfb4dc","type":"ColumnDataSource"},"glyph":{"id":"2bad7c71-a1d4-4b13-9c0b-1e0067c463ba","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"c1709b18-f460-46b0-bd50-3e584f623732","type":"Rect"},"selection_glyph":null},"id":"6f9d0547-719c-4e9c-9258-5f8208e966c0","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"field":"z","transform":{"id":"5faa71de-8a7c-4f2e-83ba-a5045aab8beb","type":"LinearColorM ...

# %% [markdown]
# ### INTEG

# %%
name = 'INTEG_AVG_AMP'
metr = integ

dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] 
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

cmap_tooltip = """
    <div>
        <div>
            <span style="font-size: 12px; font-weight: bold; color: #303030;">counts: </span>
            <span style="font-size: 13px; color: #515151">@z</span>
        </div>
        <div>
            <span style="font-size: 12px; font-weight: bold; color: #303030;">AMP: </span>
            <span style="font-size: 13px; color: #515151;">@amp</span>
        </div>
    </div>
""".replace("counts:", name+":")

hover = HoverTool(tooltips=cmap_tooltip)


p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b20527b7-f4be-4204-bba1-dfcb27e74952">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e0d831af-abc8-4255-9a82-bc3f435b55da"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e0d831af-abc8-4255-9a82-bc3f435b55da").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e0d831af-abc8-4255-9a82-bc3f435b55da");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e0d831af-abc8-4255-9a82-bc3f435b55da' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4ebb0fac-bb75-4bc6-acbd-6c81a4dd082d":{"roots":{"references":[{"attributes":{},"id":"aa7a529c-48f3-411f-beb6-336ee53d2268","type":"BasicTickFormatter"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"785d827b-a349-4efb-ab98-7f18d74f4197","subtype":"Figure","type":"Plot"},"ticker":{"id":"e88ab7e9-3f2a-405c-82b0-c6a5eaa09a7f","type":"BasicTicker"}},"id":"a3cdd490-352d-471f-94f4-a597c5e731d2","type":"Grid"},{"attributes":{"data_source":{"id":"13f98221-b5e8-4f6c-b222-72f304ad2309","type":"ColumnDataSource"},"glyph":{"id":"6e33d59c-b8ac-419c-bc11-6588322982b1","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"79fd500c-af61-421d-ab7e-9d87b611dc72","type":"Text"},"selection_glyph":null},"id":"8ef7a3c7-0f49-4794-b0f8-f4c6ee034350","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4636f798-031b-4cd4-baeb-807c2440c0d6","type":"HoverTool"}]},"id":"76b66e93-61e6-469a-938d-14a117df742e","type":"Toolbar"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"d756aea3-e648-40cb-baab-9456e587606a","type":"Range1d"},{"attributes":{"data_source":{"id":"13f98221-b5e8-4f6c-b222-72f304ad2309","type":"ColumnDataSource"},"glyph":{"id":"b104242a-14e0-460b-bbc6-08931befcdc0","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"6de0a4ea-b396-4e18-b02f-c767d4a1d468","type":"Text"},"selection_glyph":null},"id":"36f18385-d5ea-4bdc-b8a3-2b1c524208ef","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"field":"z","transform":{"id":"bdb9a382-f5ca-4ad3-af21-1611c3c7a820","type":"LinearColorMapper"}},"height":{"units":"data","value":0.98},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"b25a4d6b-d0f8-4cae-8064-3477a2e50375","type":"Rect"},{"attributes":{"callback":null,"plot":{"id":"785d827b-a349-4efb-ab98-7f18d74f4197","subtype":"Figure","type":"Plot"},"tooltips":"\n    <div>\n        <div>\n            <span style=\"font-size: 12px; font-weight: bold; color: #303030;\">INTEG_AVG_AMP: </span>\n            <span style=\"font-size: 13px; color: #515151\">@z</span>\n        </div>\n        <div>\n            <span style=\"font-size: 12px; font-weight: bold; color: #303030;\">AMP: </span>\n            <span style=\"font-size: 13px; color: #515151;\">@amp</span>\n        </div>\n    </div>\n"},"id":"4636f798-031b-4cd4-baeb-807c2440c0d6","type":"HoverTool"},{"attributes":{"data_source":{"id":"13f98221-b5e8-4f6c-b222-72f304ad2309","type":"ColumnDataSource"},"glyph":{"id":"b25a4d6b-d0f8-4cae-8064-3477a2e50375","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"fb3a17d5-6a0f-44ec-bee3-a9fb5f17d320","type":"Rect"},"selection_glyph":null},"id":"ec92a9bf-b7d9-43c8-8ad0-d2b499891517","type":"GlyphRenderer"},{"attributes":{},"id":"3ab42926-c82d-469b-b551-ade242f6ed2b","type":"BasicTickFormatter"},{"attributes":{"text":{"field":"amp"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"field":"y_offset1"}},"id":"79fd500c-af61-421d-ab7e-9d87b611dc72","type":"Text"},{"attributes":{},"id":"e3bf5679-a0ce-4e31-8de1-8f5c7db46fef","type":"BasicTicker"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"785d827b-a349-4efb-ab98-7f18d74f4197","subtype":"Figure","type":"Plot"},"ticker":{"id":"e3bf5679-a0ce-4e31-8de1-8f5c7db46fef","type":"BasicTicker"}},"id":"4066d198-f2a9-4131-8a54-384dd0b70394","type":"Grid"},{"attributes":{"plot":null,"text":"INTEG_AVG_AMP"},"id":"e0d646fe-ac08-4f06-84cc-54a65f5c0705","type":"Title"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575", ...

# %% [markdown]
# ### SKYPEAK

# %%
name = 'SUMCOUNT_RMS_AMP'
metr = skypeak

# Get Bias
dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

cmap_tooltip = """
    <div>
        <div>
            <span style="font-size: 12px; font-weight: bold; color: #303030;">counts: </span>
            <span style="font-size: 13px; color: #515151">@z</span>
        </div>
        <div>
            <span style="font-size: 12px; font-weight: bold; color: #303030;">AMP: </span>
            <span style="font-size: 13px; color: #515151;">@amp</span>
        </div>
    </div>
""".replace("counts:", name+":")

hover = HoverTool(tooltips=cmap_tooltip)


p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1c8d47dc-5378-49a6-a409-2f7e833f4616">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7a8f3c98-a2e8-4875-ae0b-636d90b97369"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7a8f3c98-a2e8-4875-ae0b-636d90b97369").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7a8f3c98-a2e8-4875-ae0b-636d90b97369");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7a8f3c98-a2e8-4875-ae0b-636d90b97369' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3d99f137-2d90-485a-8e62-400db641daa3":{"roots":{"references":[{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"e1e3b372-0cdf-43e2-8c68-2b19b41fbc29","type":"Text"},{"attributes":{},"id":"9b409f30-5e8c-4000-89b9-2b0c8d7b2560","type":"BasicTicker"},{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"e596f2c9-be6d-4bdd-896e-fc3de1c0ee5c","type":"Text"},{"attributes":{"data_source":{"id":"f7b86f82-4a71-4705-a87c-e14ad950c032","type":"ColumnDataSource"},"glyph":{"id":"1a47e6e4-db56-4c97-9d55-c45c4284ebe5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"38559d11-1d95-42e6-851a-bfed8bc8713b","type":"Rect"},"selection_glyph":null},"id":"ee1bd319-c573-4200-af87-eaa3b03a1595","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2eebef45-ce96-4488-8b64-b1a472e45dc8","type":"HoverTool"}]},"id":"21f66c6f-2c15-4215-8ede-4919010e4afd","type":"Toolbar"},{"attributes":{"formatter":{"id":"dfaeec00-d10a-4cd8-a39e-22b9bf9e6d63","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"c628471d-d881-4ff3-a936-69d3f7d89fda","subtype":"Figure","type":"Plot"},"ticker":{"id":"9b409f30-5e8c-4000-89b9-2b0c8d7b2560","type":"BasicTicker"}},"id":"1165b1f2-5eaa-42f1-9f54-ca9e66d2ffb5","type":"LinearAxis"},{"attributes":{"text":{"field":"amp"},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"field":"y_offset1"}},"id":"d447f53b-46a0-46ef-aeca-95e98a3ebf34","type":"Text"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472A79","#472B7A","#472C7B","#462D7C","#462F7C","#46307D","#46317E","#45327F","#45347F","#453580","#453681","#443781","#443982","#433A83","#433B83","#433C84","#423D84","#423E85","#424085","#414186","#414286","#404387","#404487","#3F4587","#3F4788","#3E4888","#3E4989","#3D4A89","#3D4B89","#3D4C89","#3C4D8A","#3C4E8A","#3B508A","#3B518A","#3A528B","#3A538B","#39548B","#39558B","#38568B","#38578C","#37588C","#37598C","#365A8C","#365B8C","#355C8C","#355D8C","#345E8D","#345F8D","#33608D","#33618D","#32628D","#32638D","#31648D","#31658D","#31668D","#30678D","#30688D","#2F698D","#2F6A8D","#2E6B8E","#2E6C8E","#2E6D8E","#2D6E8E","#2D6F8E","#2C708E","#2C718E","#2C728E","#2B738E","#2B748E","#2A758E","#2A768E","#2A778E","#29788E","#29798E","#287A8E","#287A8E","#287B8E","#277C8E","#277D8E","#277E8E","#267F8E","#26808E","#26818E","#25828E","#25838D","#24848D","#24858D","#24868D","#23878D","#23888D","#23898D","#22898D","#228A8D","#228B8D","#218C8D","#218D8C","#218E8C","#208F8C","#20908C","#20918C","#1F928C","#1F938B","#1F948B","#1F958B","#1F968B","#1E978A","#1E988A","#1E998A","#1E998A","#1E9A89","#1E9B89","#1E9C89","#1E9D88","#1E9E88","#1E9F88","#1EA087","#1FA187","#1FA286","#1FA386","#20A485","#20A585","#21A685","#21A784","#22A784","#23A883","#23A982","#24AA82","#25AB81","#26AC81","#27AD80","#28AE7F","#29AF7F","#2AB07E","#2BB17D","#2CB17D","#2EB27C","#2FB37B","#30B47A","#32B57A","#33B679","#35B778","#36B877","#38B976","#39B976","#3BBA75","#3DBB74","#3EBC73","#40BD72","#42BE71","#44BE70","#45BF6F","#47C06E","#49C16D","#4BC26C","#4DC26B","#4FC369","#51C468","#53C567","#55C666","#57C665","#59C764","#5BC862","#5EC9 ...

# %% [markdown]
# #### GET RMS

# %%
name = 'RMS_AMP'
metr = getrms

# Get Bias
dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

cmap_tooltip = """
    <div>
        <div>
            <span style="font-size: 12px; font-weight: bold; color: #303030;">counts: </span>
            <span style="font-size: 13px; color: #515151">@z</span>
        </div>
        <div>
            <span style="font-size: 12px; font-weight: bold; color: #303030;">AMP: </span>
            <span style="font-size: 13px; color: #515151;">@amp</span>
        </div>
    </div>
""".replace("counts:", name+":")

hover = HoverTool(tooltips=cmap_tooltip)


p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4faec206-b50f-4042-a6ad-1e559e51d8ba">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1c05e48e-9e06-49f0-b485-68a478cbf75c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1c05e48e-9e06-49f0-b485-68a478cbf75c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1c05e48e-9e06-49f0-b485-68a478cbf75c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1c05e48e-9e06-49f0-b485-68a478cbf75c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"097e6446-8a81-404a-b049-b67a7f06a8f8":{"roots":{"references":[{"attributes":{"color_mapper":{"id":"096bc8fb-85e3-4a3d-b65a-9cc05ab32dac","type":"LinearColorMapper"},"formatter":{"id":"a035f058-36da-4689-b507-ff6267f394c3","type":"BasicTickFormatter"},"label_standoff":2,"location":[1,0],"major_label_text_align":"left","major_label_text_font_size":{"value":"10pt"},"plot":{"id":"6217039d-b22f-41df-9774-2691426190cd","subtype":"Figure","type":"Plot"},"ticker":{"id":"0cd1849d-51f4-415b-a0d1-45a4a43960b7","type":"BasicTicker"}},"id":"cb6b92cb-148f-4621-9d92-21736aa67d7d","type":"ColorBar"},{"attributes":{"data_source":{"id":"5f98825b-5b0d-436e-99c1-a5ee4c93b077","type":"ColumnDataSource"},"glyph":{"id":"e3ef5bc5-9b2b-4117-ba51-967e0bceec68","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"283268ed-bd13-4dcc-9970-44bbf8b22f7f","type":"Text"},"selection_glyph":null},"id":"79bdf09a-7f3d-473c-afd6-d04021ebae54","type":"GlyphRenderer"},{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"e3ef5bc5-9b2b-4117-ba51-967e0bceec68","type":"Text"},{"attributes":{"formatter":{"id":"5bc4e36c-531e-4d9d-8833-4c8aaa6bf16b","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"6217039d-b22f-41df-9774-2691426190cd","subtype":"Figure","type":"Plot"},"ticker":{"id":"9da97967-e7fd-44f2-8120-61fe5f4b1f21","type":"BasicTicker"}},"id":"ce3be166-8e95-49f4-9ba4-e6fca4618e7d","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"field":"z","transform":{"id":"096bc8fb-85e3-4a3d-b65a-9cc05ab32dac","type":"LinearColorMapper"}},"height":{"units":"data","value":0.98},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"3d473bc4-3cdd-4e5c-9af5-e557c29a1301","type":"Rect"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"a9d18c57-8c70-4484-9263-1a3c83ee744c","type":"Range1d"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"81ea606a-bb77-42e2-961a-71c1be194bf9","type":"Range1d"},{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"283268ed-bd13-4dcc-9970-44bbf8b22f7f","type":"Text"},{"attributes":{"callback":null,"plot":{"id":"6217039d-b22f-41df-9774-2691426190cd","subtype":"Figure","type":"Plot"},"tooltips":"\n    <div>\n        <div>\n            <span style=\"font-size: 12px; font-weight: bold; color: #303030;\">RMS_AMP: </span>\n            <span style=\"font-size: 13px; color: #515151\">@z</span>\n        </div>\n        <div>\n            <span style=\"font-size: 12px; font-weight: bold; color: #303030;\">AMP: </span>\n            <span style=\"font-size: 13px; color: #515151;\">@amp</span>\n        </div>\n    </div>\n"},"id":"ad28a9a9-ce3c-4e50-8a93-099050bb9f5c","type":"HoverTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ad28a9a9-ce3c-4e50-8a93-099050bb9f5c","type":"HoverTool"}]},"id":"7327e43b-e65f-49b4-83fb-d1ce58620c9e","type":"Toolbar"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"6217039d-b22f-41df-9774-2691426190cd","subtype":"Figure","type":"Plot"},"ticker":{"id":"77633941-e4d1-49cc-bc9f-af311476aa35","type":"BasicTicker"}},"id":"550e4ca5-b200-46b2-bb7b-cff6e106fa57","type":"Grid"},{"attributes":{},"id":"caf7f477-40a8-4dd9-9177-ca37059f1878","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["y_offset1","amp","z","ztext","y_offset2","x","y"],"data":{"amp":["AMP 1","AMP 2","AMP 3","AMP 4"],"x":[0,1,0,1],"y":[1,1,0,0],"y_off ...

# %% [markdown]
# ### Comentários:
# - Ajustar colorbar
# - Adicionar o Log mode
# - Adicionar alguma tool diferente?
