# %%
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show
from bokeh.models import (LinearColorMapper ,    ColorBar)
from bokeh.palettes import (Category10_10,Accent8,BuPu5,
                    Colorblind3,RdYlBu11, YlGnBu9,Spectral3, 
                    Plasma256, RdYlBu,Colorblind, Viridis3, Viridis256)
from bokeh.io import output_notebook
import numpy as np

# %%
# =============================================
# THIS comes from INTERFACE
#
selected_exposure = '00000003'# args['exposure']
selected_arm = 'r' # args['arm']
selected_spectrograph =  4 # args['spectrograph']

# =============================================
# THIS comes from QLF.CFG
#
night = '20190101'

# ============================================
#  THIS READ yaml files
#
from scalar_metrics_v02 import LoadMetrics

cam = selected_arm+str(selected_spectrograph)
exp = selected_exposure # intentionaly redundant
lm = LoadMetrics(cam, exp, night);
metrics, tests  = lm.metrics, lm.tests 

# =============================================
# THIS is only to simplify the code understanding
#
countpix  = metrics['countpix']
getbias   = metrics['getbias']
getrms    = metrics['getrms']
xwsigma   = metrics['xwsigma']
countbins = metrics['countbins']
integ     = metrics['integ']
skycont   = metrics['skycont']
skypeak   = metrics['skypeak']
skyresid  = metrics['skyresid']
snr       = metrics['snr']
# Out:
# countpix loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-countpix-r4-00000003.yaml
# getbias loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-getbias-r4-00000003.yaml
# getrms loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-getrms-r4-00000003.yaml
# xwsigma loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-xwsigma-r4-00000003.yaml
# countbins loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-countbins-r4-00000003.yaml
# integ loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-integ-r4-00000003.yaml
# skycont loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-skycont-r4-00000003.yaml
# skypeak loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-skypeak-r4-00000003.yaml
# skyresid loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-skyresid-r4-00000003.yaml
# snr loaded
# /home/foliveira/quicklook/spectro/redux/exposures/20190101/00000003/ql-snr-r4-00000003.yaml

# %% [markdown]
# ### Get Bias

# %%
# Get Bias
name = 'BIAS_AMP'
metr = getbias

dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']

mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

hover = HoverTool(tooltips=[
         ("counts", "@z"),
         ("AMP", "@amp"),
         ])

p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="06988975-753c-4967-8dbc-d773dac818cc">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9f114f28-20f8-4be0-abf7-ca399b4faeaa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("9f114f28-20f8-4be0-abf7-ca399b4faeaa").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9f114f28-20f8-4be0-abf7-ca399b4faeaa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9f114f28-20f8-4be0-abf7-ca399b4faeaa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c4e97d1c-b5e0-49f7-8cd9-d1503c9c3d74":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y_offset1","amp","z","ztext","y_offset2","x","y"],"data":{"amp":["AMP 1","AMP 2","AMP 3","AMP 4"],"x":[0,1,0,1],"y":[1,1,0,0],"y_offset1":[1.15,1.15,0.15,0.15],"y_offset2":[0.95,0.95,-0.05,-0.05],"z":[0.19942639574034923,0.11438873228408115,0.11028779069767441,0.13507482773471147],"ztext":["1.994e-01","1.144e-01","1.103e-01","1.351e-01"]}},"id":"1762e8de-0657-4b47-becb-9ed440abdcca","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"1edefb4f-fdc9-4b2e-8c59-6cb70d822953","type":"LinearAxis"}],"left":[{"id":"c321912b-32f3-4bfe-bc03-6d3f889d0a6a","type":"LinearAxis"},{"id":"0f645604-b202-473b-ac25-1f94e2537393","type":"ColorBar"}],"outline_line_color":{"value":null},"plot_height":400,"plot_width":400,"renderers":[{"id":"1edefb4f-fdc9-4b2e-8c59-6cb70d822953","type":"LinearAxis"},{"id":"450ebc0a-9866-4a96-be74-46e78797512a","type":"Grid"},{"id":"c321912b-32f3-4bfe-bc03-6d3f889d0a6a","type":"LinearAxis"},{"id":"29138758-fc88-4c2d-be45-f8c877dae10f","type":"Grid"},{"id":"4a9dc898-e804-44b3-80d6-39310e1a3e53","type":"GlyphRenderer"},{"id":"dd054b0e-1e1e-49c9-9be0-0da4b1b26685","type":"GlyphRenderer"},{"id":"fc13323d-f262-4a3f-95a8-a4454bd18381","type":"GlyphRenderer"},{"id":"0f645604-b202-473b-ac25-1f94e2537393","type":"ColorBar"}],"title":{"id":"8cb9791c-e61d-4877-aac5-5c39cdd742bb","type":"Title"},"tool_events":{"id":"03377419-f351-4ae2-87fe-0a94fc71155d","type":"ToolEvents"},"toolbar":{"id":"ffd71e28-eddd-424d-bb35-674d1250bf60","type":"Toolbar"},"x_range":{"id":"dc203c1e-8182-42ab-bfdd-0a794b0d2acb","type":"Range1d"},"y_range":{"id":"92cdbba0-c276-4831-907b-db6d3ba48b8f","type":"Range1d"}},"id":"9a847488-88a1-40ee-8bfb-880f8242e61f","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"a906be07-dce3-472a-8048-c0dbcd50f83d","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"9a847488-88a1-40ee-8bfb-880f8242e61f","subtype":"Figure","type":"Plot"},"ticker":{"id":"209784d6-e349-4228-ade5-23553186e44f","type":"BasicTicker"}},"id":"1edefb4f-fdc9-4b2e-8c59-6cb70d822953","type":"LinearAxis"},{"attributes":{"data_source":{"id":"1762e8de-0657-4b47-becb-9ed440abdcca","type":"ColumnDataSource"},"glyph":{"id":"71e2b190-95ce-4876-ad33-506729fab17e","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"52c5e6b7-6b1b-4a11-80ac-ce6ff73dc881","type":"Text"},"selection_glyph":null},"id":"fc13323d-f262-4a3f-95a8-a4454bd18381","type":"GlyphRenderer"},{"attributes":{},"id":"f1204466-2fb2-418e-8717-ca620b74cb9b","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.98},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"9cd3c22f-c171-4aea-868d-e2ce1770278e","type":"Rect"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5bf3284d-82ae-4ea5-a192-31d38230b06c","type":"HoverTool"}]},"id":"ffd71e28-eddd-424d-bb35-674d1250bf60","type":"Toolbar"},{"attributes":{},"id":"209784d6-e349-4228-ade5-23553186e44f","type":"BasicTicker"},{"attributes":{},"id":"3db0c6c4-ae6f-49ae-b92c-ff6731cb810b","type":"BasicTickFormatter"},{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"8cd352e8-64d7-41b4-8ea4-aff9f6ddffa0","type":"Text"},{"attributes":{"plot":null,"text":"BIAS_AMP"},"id":"8cb9791c-e61d-4877-aac5-5c39cdd742bb","type":"Title"},{"attributes":{},"id":"03377419-f351-4ae2-87fe-0a94fc71155d","type":"ToolEvents"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"i ...

# %%
# Out:
# dict_keys(['DATA5SIG', 'BIAS_AMP', 'DIFF3SIG', 'DIFF1SIG', 'BIASDIFF_ERR', 'MEANBIAS_ROW', 'DIFF2SIG', 'BIAS'])

# %% [markdown]
# ### Countpix

# %%
name = 'NPIX_LOW_AMP'
metr = countpix

# Get Bias
dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

hover = HoverTool(tooltips=[
         ("counts", "@z"),
         ("AMP", "@amp"),
         ])

p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="00147da1-0653-485b-aa7a-af532b292fdc">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="11759e54-898f-4f17-9e20-aafb086b1006"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("11759e54-898f-4f17-9e20-aafb086b1006").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("11759e54-898f-4f17-9e20-aafb086b1006");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '11759e54-898f-4f17-9e20-aafb086b1006' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e5dbe0b9-8ee1-4600-ac4a-1ec14ac86af3":{"roots":{"references":[{"attributes":{"text":{"field":"amp"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"field":"y_offset1"}},"id":"d0f11ec3-299a-4a04-988a-15df95116cea","type":"Text"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"field":"z","transform":{"id":"324e44b7-3572-4a00-8c38-c93690a43ea4","type":"LinearColorMapper"}},"height":{"units":"data","value":0.98},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"e934da9b-79c6-40ce-902d-5d5e1154a723","type":"Rect"},{"attributes":{"formatter":{"id":"0c694378-4992-4ad5-aa10-6fcc17129240","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"63851bce-9402-4604-af40-1a463250766a","subtype":"Figure","type":"Plot"},"ticker":{"id":"0ff41efc-20af-42b6-883f-c034e2280be6","type":"BasicTicker"}},"id":"dfa2127e-5f49-4868-9a6a-6aaf81ab112a","type":"LinearAxis"},{"attributes":{},"id":"0ff41efc-20af-42b6-883f-c034e2280be6","type":"BasicTicker"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"63851bce-9402-4604-af40-1a463250766a","subtype":"Figure","type":"Plot"},"ticker":{"id":"0ff41efc-20af-42b6-883f-c034e2280be6","type":"BasicTicker"}},"id":"39cb6c2f-e195-4153-a4cb-04468549ad5c","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.98},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"10c70bd9-c826-49c8-b58e-0d04ab1e3212","type":"Rect"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"63851bce-9402-4604-af40-1a463250766a","subtype":"Figure","type":"Plot"},"ticker":{"id":"f05a5add-c6f6-4cca-a725-fa47c3413f23","type":"BasicTicker"}},"id":"7b4a34b5-b62e-44c9-a97a-5665b7e550d7","type":"Grid"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"bb9f5331-db2a-4dde-8c59-cb5391d903d9","type":"Range1d"},{"attributes":{},"id":"0c694378-4992-4ad5-aa10-6fcc17129240","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"ace91678-46c6-409a-9f94-68e537d2d050","type":"ColumnDataSource"},"glyph":{"id":"4fa85c5e-e6a6-4180-81cd-0866d5a7cbda","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"fb4db676-8e8e-4c5b-ba7c-5bb7c1485f68","type":"Text"},"selection_glyph":null},"id":"25035d94-da03-4f15-a4e7-fdf81b741540","type":"GlyphRenderer"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472A79","#472B7A","#472C7B","#462D7C","#462F7C","#46307D","#46317E","#45327F","#45347F","#453580","#453681","#443781","#443982","#433A83","#433B83","#433C84","#423D84","#423E85","#424085","#414186","#414286","#404387","#404487","#3F4587","#3F4788","#3E4888","#3E4989","#3D4A89","#3D4B89","#3D4C89","#3C4D8A","#3C4E8A","#3B508A","#3B518A","#3A528B","#3A538B","#39548B","#39558B","#38568B","#38578C","#37588C","#37598C","#365A8C","#365B8C","#355C8C","#355D8C","#345E8D","#345F8D","#33608D","#33618D","#32628D","#32638D","#31648D","#31658D","#31668D","#30678D","#30688D","#2F698D","#2F6A8D","#2E6B8E","#2E6C8E","#2E6D8E","#2D6E8E","#2D6F8E","#2C708E","#2C718E","#2C728E","#2B738E","#2B748E","#2A758E","#2A768E","#2A778E","#29788E","#29798E","#287A8E","#287A8E","#287B8E","#277C8E","#277D8E","#277E8E","#267F8E","#26808E","#26818E","#25828E","#25838D","#24848D","#24858D","#24868D","#23878D","#23888D","#23898D","#22898D","#228A8D","#228B8D","#218C8D","#218D8C","#218E8C","#208F ...

# %% [markdown]
# ### INTEG

# %%
name = 'INTEG_AVG_AMP'
metr = integ

# Get Bias
dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

hover = HoverTool(tooltips=[
         ("counts", "@z"),
         ("AMP", "@amp"),
         ])

p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="03d41281-2418-4a4e-a1f8-4081c93ff3fa">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="673e5474-fc74-4fbf-8c5e-1fe3ac079312"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("673e5474-fc74-4fbf-8c5e-1fe3ac079312").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("673e5474-fc74-4fbf-8c5e-1fe3ac079312");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '673e5474-fc74-4fbf-8c5e-1fe3ac079312' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"37a197c6-721e-401a-99aa-eaf2b317bdd9":{"roots":{"references":[{"attributes":{"data_source":{"id":"ec7d14a4-c47f-4ad2-8379-4807ce0d334f","type":"ColumnDataSource"},"glyph":{"id":"60326a86-97ad-401d-87e3-d81cb124a69b","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"5b661db7-2e3c-40e8-8d5a-3096bf8c7a27","type":"Text"},"selection_glyph":null},"id":"82dcbd25-ed58-42b1-9fdf-ad656993cdc7","type":"GlyphRenderer"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"004db1cb-0def-460e-bbb5-4a6062b70aee","subtype":"Figure","type":"Plot"},"ticker":{"id":"02cf289a-6b39-4235-9855-f32bcb17818c","type":"BasicTicker"}},"id":"9858e98e-2ef9-4353-8c3b-1302c77a2dea","type":"Grid"},{"attributes":{"text":{"field":"ztext"},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"20pt"},"text_font_style":"bold","x":{"field":"x"},"y":{"field":"y_offset2"}},"id":"5b661db7-2e3c-40e8-8d5a-3096bf8c7a27","type":"Text"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472A79","#472B7A","#472C7B","#462D7C","#462F7C","#46307D","#46317E","#45327F","#45347F","#453580","#453681","#443781","#443982","#433A83","#433B83","#433C84","#423D84","#423E85","#424085","#414186","#414286","#404387","#404487","#3F4587","#3F4788","#3E4888","#3E4989","#3D4A89","#3D4B89","#3D4C89","#3C4D8A","#3C4E8A","#3B508A","#3B518A","#3A528B","#3A538B","#39548B","#39558B","#38568B","#38578C","#37588C","#37598C","#365A8C","#365B8C","#355C8C","#355D8C","#345E8D","#345F8D","#33608D","#33618D","#32628D","#32638D","#31648D","#31658D","#31668D","#30678D","#30688D","#2F698D","#2F6A8D","#2E6B8E","#2E6C8E","#2E6D8E","#2D6E8E","#2D6F8E","#2C708E","#2C718E","#2C728E","#2B738E","#2B748E","#2A758E","#2A768E","#2A778E","#29788E","#29798E","#287A8E","#287A8E","#287B8E","#277C8E","#277D8E","#277E8E","#267F8E","#26808E","#26818E","#25828E","#25838D","#24848D","#24858D","#24868D","#23878D","#23888D","#23898D","#22898D","#228A8D","#228B8D","#218C8D","#218D8C","#218E8C","#208F8C","#20908C","#20918C","#1F928C","#1F938B","#1F948B","#1F958B","#1F968B","#1E978A","#1E988A","#1E998A","#1E998A","#1E9A89","#1E9B89","#1E9C89","#1E9D88","#1E9E88","#1E9F88","#1EA087","#1FA187","#1FA286","#1FA386","#20A485","#20A585","#21A685","#21A784","#22A784","#23A883","#23A982","#24AA82","#25AB81","#26AC81","#27AD80","#28AE7F","#29AF7F","#2AB07E","#2BB17D","#2CB17D","#2EB27C","#2FB37B","#30B47A","#32B57A","#33B679","#35B778","#36B877","#38B976","#39B976","#3BBA75","#3DBB74","#3EBC73","#40BD72","#42BE71","#44BE70","#45BF6F","#47C06E","#49C16D","#4BC26C","#4DC26B","#4FC369","#51C468","#53C567","#55C666","#57C665","#59C764","#5BC862","#5EC961","#60C960","#62CA5F","#64CB5D","#67CC5C","#69CC5B","#6BCD59","#6DCE58","#70CE56","#72CF55","#74D054","#77D052","#79D151","#7CD24F","#7ED24E","#81D34C","#83D34B","#86D449","#88D547","#8BD546","#8DD644","#90D643","#92D741","#95D73F","#97D83E","#9AD83C","#9DD93A","#9FD938","#A2DA37","#A5DA35","#A7DB33","#AADB32","#ADDC30","#AFDC2E","#B2DD2C","#B5DD2B","#B7DD29","#BADE27","#BDDE26","#BFDF24","#C2DF22","#C5DF21","#C7E01F","#CAE01E","#CDE01D","#CFE11C","#D2E11B","#D4E11A","#D7E219","#DAE218","#DCE218","#DFE318","#E1E318","#E4E318","#E7E419","#E9E419","#ECE41A","#EEE51B","#F1E51C","#F3E51E","#F6E61F","#F8E621","#FAE622","#FDE724"]},"id":"b2598ed0-e190-4abd-805d-fb417269435a","type":"LinearColorMapper"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"bfb16559-0ff0-48d2-a851-185c5e873355","type":"Range1d"},{"attributes":{"text":{"field":"amp"},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"18pt"},"x":{"field":"x"},"y":{"fiel ...

# %% [markdown]
# ### SKYPEAK

# %%
name = 'SUMCOUNT_RMS_AMP'
metr = skypeak

# Get Bias
dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

hover = HoverTool(tooltips=[
         ("counts", "@z"),
         ("AMP", "@amp"),
         ])

p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4f8b10f8-e5ea-4264-8c13-958f7337dfe2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b4f574dc-eb31-4497-a874-2fcf7cd85a45"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b4f574dc-eb31-4497-a874-2fcf7cd85a45").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b4f574dc-eb31-4497-a874-2fcf7cd85a45");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b4f574dc-eb31-4497-a874-2fcf7cd85a45' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"302acc27-2582-4f39-b709-5f15a72a2908":{"roots":{"references":[{"attributes":{},"id":"3c1f997d-730e-44bb-9b75-d7b2e82311b7","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"cc315cc4-7cd1-49f8-b27a-95855c4d5e91","type":"ColumnDataSource"},"glyph":{"id":"c9fb479d-eb15-4054-8c35-f5c6e6d877cd","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"98a42de3-8e4a-4243-b5b2-8ff430293c75","type":"Text"},"selection_glyph":null},"id":"bbc40c2c-9c1f-43dc-a996-ef442eaa8ae4","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"8ad48f4b-7f1a-4162-bed6-d8596a819ff9","type":"Range1d"},{"attributes":{"plot":null,"text":"SUMCOUNT_RMS_AMP"},"id":"0d2a60e5-0480-4279-8931-b562920d28af","type":"Title"},{"attributes":{"formatter":{"id":"3c1f997d-730e-44bb-9b75-d7b2e82311b7","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"0e6a0d1a-0f5a-46b0-8845-7b768f2f6185","subtype":"Figure","type":"Plot"},"ticker":{"id":"61c12352-842d-4f07-a932-6c21be4822d3","type":"BasicTicker"}},"id":"54b301ff-cf24-428c-98dc-9f0030612724","type":"LinearAxis"},{"attributes":{},"id":"c58a0894-20f7-4e91-b9e9-e52f7193ded3","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["y_offset1","amp","z","ztext","y_offset2","x","y"],"data":{"amp":["AMP 1","AMP 2","AMP 3","AMP 4"],"x":[0,1,0,1],"y":[1,1,0,0],"y_offset1":[1.15,1.15,0.15,0.15],"y_offset2":[0.95,0.95,-0.05,-0.05],"z":["NaN",18.07457712351294,"NaN",6.845803467534718],"ztext":[" nan","1.807e+01"," nan","6.846e+00"]}},"id":"cc315cc4-7cd1-49f8-b27a-95855c4d5e91","type":"ColumnDataSource"},{"attributes":{},"id":"3f387865-37cf-495e-ab0b-de73fde2a55a","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"field":"z","transform":{"id":"2dc0df89-a86b-45e9-9be9-47df814ed81f","type":"LinearColorMapper"}},"height":{"units":"data","value":0.98},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"8edaeee7-2121-4236-aa51-08cbea7ae278","type":"Rect"},{"attributes":{},"id":"3fbad9b6-117a-498a-8bed-d17b0e219a88","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"0e6a0d1a-0f5a-46b0-8845-7b768f2f6185","subtype":"Figure","type":"Plot"},"ticker":{"id":"61c12352-842d-4f07-a932-6c21be4822d3","type":"BasicTicker"}},"id":"39d9a4d9-15f3-4783-a25a-ca25c0e17ef1","type":"Grid"},{"attributes":{},"id":"2477f15f-9668-46ec-8f95-54aa36eec918","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"ae61c90e-e704-423d-98c9-ef570596083b","type":"Range1d"},{"attributes":{"color_mapper":{"id":"2dc0df89-a86b-45e9-9be9-47df814ed81f","type":"LinearColorMapper"},"formatter":{"id":"2477f15f-9668-46ec-8f95-54aa36eec918","type":"BasicTickFormatter"},"label_standoff":2,"location":[1,0],"major_label_text_align":"left","major_label_text_font_size":{"value":"10pt"},"plot":{"id":"0e6a0d1a-0f5a-46b0-8845-7b768f2f6185","subtype":"Figure","type":"Plot"},"ticker":{"id":"3f387865-37cf-495e-ab0b-de73fde2a55a","type":"BasicTicker"}},"id":"5382c3d7-994c-48a5-9880-4bfd18aa9fdd","type":"ColorBar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.98},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.98},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d3e82a7-1b8d-4311-bc8d-c73eb0dedee9","type":"Rect"},{"attributes":{"formatter":{"id":"3fbad9b6-117a-498a-8bed-d17b0e219a88","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"0e6a0d1a-0f5a-46b0-8845-7b768f2f6185","subtype":"Figure","type":"Plot"},"ticker":{"id":"79fbcb5a-a1ee-4a79-9199-497348345a39","type":"BasicTicker"}},"id":"6f300d10-b5f9-42e1- ...

# %% [markdown]
# #### GET RMS

# %%
name = 'RMS_AMP'
metr = getrms

# Get Bias
dx = [0,1,0,1]
dy = [1,1,0,0]
dz = metr[name] #getbias['BIAS_AMP']
mapper = LinearColorMapper(palette= Viridis256)


source = ColumnDataSource(
    data=dict(
        x=dx,
        y=dy,
        y_offset1 = [i+0.15 for i in dy],
        y_offset2 = [i-0.05 for i in dy],

        z = dz,
        amp = ['AMP %s'%i for i in range(1,5) ] ,
        ztext = ['{:4.3e}'.format(i) for i in dz]
    )
)

hover = HoverTool(tooltips=[
         ("counts", "@z"),
         ("AMP", "@amp"),
         ])

p = figure(title=name, tools=[hover],
           x_range= list([-0.5,1.5]),           # length = 18
           y_range= list([-0.5,1.5]), #numeros romanos
           plot_width=400, plot_height=400
          )


p.grid.grid_line_color = None
p.outline_line_color = None
p.axis.clear

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_color":"black",
    "text_align": "center",
    "text_baseline": "middle"
}



p.rect("x", "y", .98, .98, 0, source=source,
       fill_color={'field': 'z', 'transform': mapper}, fill_alpha=0.9)#, color="color")
p.axis.minor_tick_line_color=None

p.text(x="x", y="y_offset2", text="ztext",
       text_font_style="bold", text_font_size="20pt", **text_props)
p.text(x="x", y="y_offset1", text="amp",
        text_font_size="18pt", **text_props)
color_bar = ColorBar(color_mapper=mapper,  major_label_text_align='left',
                major_label_text_font_size='10pt', label_standoff=2,location=(1, 0))

p.add_layout(color_bar, 'left')


p.xaxis.major_label_text_font_size = '0pt'  # turn off x-axis tick labels
p.yaxis.major_label_text_font_size = '0pt'  # turn off y-axis tick labels
p.xaxis.major_tick_line_color = None  # turn off x-axis major ticks
p.xaxis.minor_tick_line_color = None  # turn off x-axis minor ticks

p.yaxis.major_tick_line_color = None  # turn off y-axis major ticks
p.yaxis.minor_tick_line_color = None  # turn off y-axis minor ticks

output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="719ca76c-a1c6-4e5b-9825-feeda537269e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="987617b6-87ec-4235-a601-06c339085cfc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("987617b6-87ec-4235-a601-06c339085cfc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("987617b6-87ec-4235-a601-06c339085cfc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '987617b6-87ec-4235-a601-06c339085cfc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e2685bc8-1c0c-4bec-a33a-d84e72dd8b5a":{"roots":{"references":[{"attributes":{"color_mapper":{"id":"ed3e0745-b658-4588-b87f-bfb47ced3199","type":"LinearColorMapper"},"formatter":{"id":"8a7437f0-d5b2-4e45-b42d-7e1e256ce3d5","type":"BasicTickFormatter"},"label_standoff":2,"location":[1,0],"major_label_text_align":"left","major_label_text_font_size":{"value":"10pt"},"plot":{"id":"3422b374-f4d0-4cf3-b12d-0f920f939a17","subtype":"Figure","type":"Plot"},"ticker":{"id":"a6894e91-c256-4d26-b1ca-fd6bf6b9499a","type":"BasicTicker"}},"id":"f293ac5a-fe02-407c-8fd7-a4ff67b7ce16","type":"ColorBar"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"c2889b3b-e96b-4a23-ad7a-e922457669f3","type":"Range1d"},{"attributes":{"callback":null,"plot":{"id":"3422b374-f4d0-4cf3-b12d-0f920f939a17","subtype":"Figure","type":"Plot"},"tooltips":[["counts","@z"],["AMP","@amp"]]},"id":"b8fa03e0-911c-4b44-8adc-3736cc2073c3","type":"HoverTool"},{"attributes":{"formatter":{"id":"bc2c2813-34f8-44b3-be6e-ce85cd423de3","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"0pt"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"3422b374-f4d0-4cf3-b12d-0f920f939a17","subtype":"Figure","type":"Plot"},"ticker":{"id":"5b893d9f-1cc1-4ae8-bd3f-2d20d6d0978c","type":"BasicTicker"}},"id":"35cf3ff1-c587-4f1b-828e-668d1f12441a","type":"LinearAxis"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"02f9411a-d7e3-4c31-a1b0-0f882611deed","type":"Range1d"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472A79","#472B7A","#472C7B","#462D7C","#462F7C","#46307D","#46317E","#45327F","#45347F","#453580","#453681","#443781","#443982","#433A83","#433B83","#433C84","#423D84","#423E85","#424085","#414186","#414286","#404387","#404487","#3F4587","#3F4788","#3E4888","#3E4989","#3D4A89","#3D4B89","#3D4C89","#3C4D8A","#3C4E8A","#3B508A","#3B518A","#3A528B","#3A538B","#39548B","#39558B","#38568B","#38578C","#37588C","#37598C","#365A8C","#365B8C","#355C8C","#355D8C","#345E8D","#345F8D","#33608D","#33618D","#32628D","#32638D","#31648D","#31658D","#31668D","#30678D","#30688D","#2F698D","#2F6A8D","#2E6B8E","#2E6C8E","#2E6D8E","#2D6E8E","#2D6F8E","#2C708E","#2C718E","#2C728E","#2B738E","#2B748E","#2A758E","#2A768E","#2A778E","#29788E","#29798E","#287A8E","#287A8E","#287B8E","#277C8E","#277D8E","#277E8E","#267F8E","#26808E","#26818E","#25828E","#25838D","#24848D","#24858D","#24868D","#23878D","#23888D","#23898D","#22898D","#228A8D","#228B8D","#218C8D","#218D8C","#218E8C","#208F8C","#20908C","#20918C","#1F928C","#1F938B","#1F948B","#1F958B","#1F968B","#1E978A","#1E988A","#1E998A","#1E998A","#1E9A89","#1E9B89","#1E9C89","#1E9D88","#1E9E88","#1E9F88","#1EA087","#1FA187","#1FA286","#1FA386","#20A485","#20A585","#21A685","#21A784","#22A784","#23A883","#23A982","#24AA82","#25AB81","#26AC81","#27AD80","#28AE7F","#29AF7F","#2AB07E","#2BB17D","#2CB17D","#2EB27C","#2FB37B","#30B47A","#32B57A","#33B679","#35B778","#36B877","#38B976","#39B976","#3BBA75","#3DBB74","#3EBC73","#40BD72","#42BE71","#44BE70","#45BF6F","#47C06E","#49C16D","#4BC26C","#4DC26B","#4FC369","#51C468","#53C567","#55C666","#57C665","#59C764","#5BC862","#5EC961","#60C960","#62CA5F","#64CB5D","#67CC5C","#69CC5B","#6BCD59","#6DCE58","#70CE56","#72CF55","#74D054","#77D052","#79D151","#7CD24F","#7ED24E","#81D34C","#83D34B","#86D449","#88D547","#8BD546","#8DD644","#90D643","#92D741","#95D73F","#97D83E","#9AD83C","#9DD93A","#9FD938","#A2DA37","#A5DA35","#A7DB33","#AADB32","#ADDC30","#AFDC2E","#B2DD2C","#B5DD2B","#B7DD29","#BADE27","#BDDE26","#BFDF24","#C2DF22","#C5DF21","#C7E01F","#CAE01E","#CDE01D","#CFE11C","#D2E11B","#D4E11A","#D7E219","#DAE218","#DCE218","#DFE318"," ...

# %% [markdown]
# ### Comentários:
# Ajustar colorbar
#
# Adicionar o Log mode
#
# Adicionar alguma tool diferente?

# %%
getrms.keys()
# Out:
# dict_keys(['RMS_ROW', 'RMS_OVER', 'RMS_OVER_AMP', 'EXPNUM_WARN', 'RMS', 'RMSDIFF_ERR', 'RMS_AMP'])
